# %%
from data import *
from models import *

# %matplotlib inline 
import matplotlib.pyplot as plt
# plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False 

pd.set_option('display.max_rows', 100)    
pd.set_option('display.max_colwidth', 100)    

# %load_ext autoreload
# %autoreload 2

data_path = os.getcwd() + "/data"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
kb_file = os.path.join(data_path,'kb_question.csv')
if os.path.exists(kb_file):
    kb_question = pd.read_csv(kb_file)
else:
    kb_question = read_kb(data_path)
    kb_question.to_csv(kb_file , index=False, encoding='utf-8-sig')

# %%
train, dev, test = np.split(kb_question.sample(frac=1), [int(.8*len(kb_question)), int(.9*len(kb_question))])

# %%
if not os.path.exists(os.path.join(data_path,'train.csv')):
    train_df = create_pair_data(train)
    train_df.to_csv(os.path.join(data_path,'train.csv'), index=False, header=False, encoding='utf_8_sig')
else:
    train_df = pd.read_csv(os.path.join(data_path,'train.csv'), header=None)
    train_df.columns = ['s1', 's2', 'score']
    
if not os.path.exists(os.path.join(data_path,'dev.csv')):
    dev_df = create_pair_data(dev)
    dev_df.to_csv(os.path.join(data_path,'dev.csv'), index=False, header=False, encoding='utf_8_sig')
else:
    dev_df = pd.read_csv(os.path.join(data_path,'dev.csv'), header=None)
    dev_df.columns = ['s1', 's2', 'score']
    
if not os.path.exists(os.path.join(data_path,'test.csv')):
    test_df = create_pair_data(test)
    test_df.to_csv(os.path.join(data_path,'test.csv'), index=False, header=False, encoding='utf_8_sig')
else:
    test_df = pd.read_csv(os.path.join(data_path,'test.csv'), header=None)
    test_df.columns = ['s1', 's2', 'score']

# %%
train, dev, test = get_nl(data_path)
# Out:
# processing /Users/tingchunyeh/tingchun/Sentence_sim/data/train.csv ...
# ** TRAIN DATA : Found 1059825 pairs of train sentences.
# processing /Users/tingchunyeh/tingchun/Sentence_sim/data/dev.csv ...
# ** DEV DATA : Found 120200 pairs of dev sentences.
# processing /Users/tingchunyeh/tingchun/Sentence_sim/data/test.csv ...
# ** TEST DATA : Found 120318 pairs of test sentences.

# %%
txt = np.append(train['s1'], train['s2'])

# %%
wv, default_wv = build_vocab(txt, "w2v-model.txt")
# Out:
# Found 5190(/5759) words with w2v vectors
# vocab size: 5759

# %%
config_nli_model = {
    'n_words'        :  len(wv),
    'word_emb_dim'   :  300,
    'enc_lstm_dim'   :  512,
    'n_enc_layers'   :  1,
    'dpout_model'    :  0,
    'dpout_fc'       :  0.3,
    'dpout_embed'    :  0.3,
    'fc_dim'         :  256,
    'bsize'          :  64,
    'n_classes'      :  3,
    'pool_type'      :  'max',
    'encoder_type'   :  'GRUEncoder',
    'use_cuda'       :  False,
    'num_layer'      :  1,
}

# %%
np.random.seed(10)
torch.manual_seed(10)
if config_nli_model['use_cuda']:
    torch.cuda.set_device(0)
    torch.cuda.manual_seed(10)

# %%
from models import *
nli_net = NLINet(config_nli_model)

# %%
# nli_net.load_state_dict(torch.load(os.path.join("saved_model", "model_1")))

# %%
# loss 
weight = torch.FloatTensor(3).fill_(1)
loss_fn = nn.CrossEntropyLoss(weight=weight)
loss_fn.size_average = False


# optimizer
from torch import optim
optimizer = optim.Adam(nli_net.parameters(), lr=0.0001)

# %%
if config_nli_model['use_cuda']:
    nli_net.cuda()
    loss_fn.cuda()

# %%
print(nli_net)
# Out:
# NLINet(
#   (encoder): GRUEncoder(
#     (enc_lstm): GRU(300, 512, bidirectional=True)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.3)
#     (1): Linear(in_features=4096, out_features=256, bias=True)
#     (2): Tanh()
#     (3): Dropout(p=0.3)
#     (4): Linear(in_features=256, out_features=3, bias=True)
#     (5): Softmax()
#   )
# )

# %%
nli_net.train()
permutation = np.random.permutation(len(train['s1']))
s1 = train['s1'][permutation]
s2 = train['s2'][permutation]
target = train['label'][permutation]
bsize = 64
for stidx in range(0, len(s1), bsize):
    s1_batch, s1_len = get_batch(s1[stidx:stidx+bsize], wv, default_wv)
    s2_batch, s2_len = get_batch(s2[stidx:stidx+bsize], wv, default_wv)

    s1_batch, s2_batch = Variable(s1_batch), Variable(s2_batch)
    tgt_batch = Variable(torch.LongTensor(target[stidx:stidx+bsize]))
    
    k = s1_batch.size(1)
    output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))
# Out:
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# torch.Size([64, 1024])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-f437eb2b9d48> in <module>()
#      14
#      15     k = s1_batch.size(1)
# ---> 16     output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/tingchun/Sentence_sim/models.py in forward(self, s1, s2)
#      87
#      88     def forward(self, s1, s2):
# ---> 89         u = self.encoder(s1)
#      90         v = self.encoder(s2)
#      91         features = torch.cat((u, v, torch.abs(u-v), u*v), 1)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/tingchun/Sentence_sim/models.py in forward(self, sent_tuple)
#      48         # Handling padding in Recurrent Networks
#      49         sent_packed = nn.utils.rnn.pack_padded_sequence(sent, sent_len)
# ---> 50         sent_output, hidden = self.enc_lstm(sent_packed, self.init_lstm)
#      51         emb = torch.cat((hidden[0], hidden[1]), 1) # batch x 2*nhid
#      52
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     190             flat_weight=flat_weight
#     191         )
# --> 192         output, hidden = func(input, self.all_weights, hx, batch_sizes)
#     193         if is_packed:
#     194             output = PackedSequence(output, batch_sizes)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     321             func = decorator(func)
#     322
# --> 323         return func(input, *fargs, **fkwargs)
#     324
#     325     return forward
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, weight, hidden, batch_sizes)
#     241             input = input.transpose(0, 1)
#     242
# --> 243         nexth, output = func(input, hidden, weight, batch_sizes)
#     244
#     245         if batch_first and not variable_length:
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight, batch_sizes)
#      84                 l = i * num_directions + j
#      85
# ---> 86                 hy, output = inner(input, hidden[l], weight[l], batch_sizes)
#      87                 next_hidden.append(hy)
#      88                 all_output.append(output)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, hidden, weight, batch_sizes)
#     195
#     196             if flat_hidden:
# --> 197                 hidden = (inner(step_input, hidden[0], *weight),)
#     198             else:
#     199                 hidden = inner(step_input, hidden, *weight)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in GRUCell(input, hidden, w_ih, w_hh, b_ih, b_hh)
#      55
#      56     gi = F.linear(input, w_ih, b_ih)
# ---> 57     gh = F.linear(hidden, w_hh, b_hh)
#      58     i_r, i_i, i_n = gi.chunk(3, 1)
#      59     h_r, h_i, h_n = gh.chunk(3, 1)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     990     if input.dim() == 2 and bias is not None:
#     991         # fused op is marginally faster
# --> 992         return torch.addmm(bias, input, weight.t())
#     993
#     994     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
def trainepoch(epoch, bsize = 64):
    all_costs = []
    tot_costs = []
    logs = []
    correct = 0.0
    
    nli_net.train()
    permutation = np.random.permutation(len(train['s1']))
    s1 = train['s1'][permutation]
    s2 = train['s2'][permutation]
    target = train['label'][permutation]
    
    for stidx in range(0, len(s1), bsize):
        s1_batch, s1_len = get_batch(s1[stidx:stidx+bsize], wv, default_wv)
        s2_batch, s2_len = get_batch(s2[stidx:stidx+bsize], wv, default_wv)

        if config_nli_model['use_cuda']:
            s1_batch, s2_batch = Variable(s1_batch.cuda()), Variable(s2_batch.cuda())
            tgt_batch = Variable(torch.LongTensor(target[stidx:stidx+bize])).cuda()
        else:
            s1_batch, s2_batch = Variable(s1_batch), Variable(s2_batch)
            tgt_batch = Variable(torch.LongTensor(target[stidx:stidx+bsize]))
        k = s1_batch.size(1)
        output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))

        pred = output.data.max(1)[1]
        correct += pred.long().eq(tgt_batch.data.long()).cpu().sum().item()

        # loss
        loss = loss_fn(output, tgt_batch)
        all_costs.append(loss.item())
        tot_costs.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if len(all_costs) == 100:
            logs.append('{0} ; loss {1}  ; accuracy train : {2}'.format(stidx, 
                            round(np.mean(all_costs), 2), round(100.*correct/(stidx+k), 2)))
            print(logs[-1])
            all_costs = []
            
    train_acc = round(100 * correct/len(s1), 2)
    train_loss = round(np.mean(tot_costs), 2)
    return train_loss, train_acc

# %%
val_acc_best = -1e10
adam_stop = False
stop_training = False

def evaluate(epoch, bsize = 64, eval_type='dev', final_eval=False):
    nli_net.eval()
    correct = 0.0
    global val_acc_best, lr, stop_training, adam_stop
    
    s1 = dev['s1'] if eval_type == 'dev' else test['s1']
    s2 = dev['s2'] if eval_type == 'dev' else test['s2']
    target = dev['label'] if eval_type == 'dev' else test['label']

    for i in range(0, len(s1), bsize):
        # prepare batch
        s1_batch, s1_len = get_batch(s1[i:i + bsize], wv, default_wv)
        s2_batch, s2_len = get_batch(s2[i:i + bsize], wv, default_wv)
        if config_nli_model['use_cuda']:
            s1_batch, s2_batch = Variable(s1_batch.cuda()), Variable(s2_batch.cuda())
            tgt_batch = Variable(torch.LongTensor(target[i:i + bsize])).cuda()
        else:
            s1_batch, s2_batch = Variable(s1_batch), Variable(s2_batch)
            tgt_batch = Variable(torch.LongTensor(target[i:i + bsize]))

        # model forward
        output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))

        pred = output.data.max(1)[1]
        correct += pred.long().eq(tgt_batch.data.long()).cpu().sum().item()

    # save model
    eval_acc = round(100 * correct / len(s1), 2)
    if final_eval:
        print('finalgrep : accuracy {0} : {1}'.format(eval_type, eval_acc))
    else:
        print('togrep : results : epoch {0} ; mean accuracy {1} :{2}'.format(epoch, eval_type, eval_acc))

    if eval_type == 'dev' and eval_acc > val_acc_best:
        print('saving model at epoch {0}'.format(epoch))
        if not os.path.exists("saved_model"): os.makedirs("saved_model")
        torch.save(nli_net.state_dict(), os.path.join("saved_model", "model_1"))
        val_acc_best = eval_acc

    return eval_acc

# %%
### TRAINING 

train_loss_ls = []
train_acc_ls = []
eval_acc_ls = []
for i in range(100):
    print('\nTRAINING : Epoch ' + str(i))
    train_loss, train_acc = trainepoch(i)
    train_loss_ls.append(train_loss)
    train_acc_ls.append(train_acc)
    print('results : epoch {0} ; loss: {1} mean accuracy train : {2}'.format(i, train_loss, train_acc))
    if i%1==0:
        print("-"*100)
        print('\nEVALIDATING : Epoch ' + str(i))
        eval_acc = evaluate(i, bsize = 64, eval_type='dev', final_eval=False)
        eval_acc_ls.append(eval_acc)
        print('results : epoch {0} ;  mean accuracy dev : {1}'.format(i, eval_acc))
        print("-"*100)
# Out:
# TRAINING : Epoch 0
# 6336 ; loss 65.15  ; accuracy train : 52.42
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-62e76305c21c> in <module>()
#       6 for i in range(100):
#       7     print('\nTRAINING : Epoch ' + str(i))
# ----> 8     train_loss, train_acc = trainepoch(i)
#       9     train_loss_ls.append(train_loss)
#      10     train_acc_ls.append(train_acc)
#
# <ipython-input-33-d4f647e2a866> in trainepoch(epoch, bsize)
#      22             tgt_batch = Variable(torch.LongTensor(target[stidx:stidx+bsize]))
#      23         k = s1_batch.size(1)
# ---> 24         output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))
#      25
#      26         pred = output.data.max(1)[1]
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/tingchun/Sentence_sim/models.py in forward(self, s1, s2)
#      86                 v = self.encoder(s2)
#      87                 features = torch.cat((u, v, torch.abs(u-v), u*v), 1)
# ---> 88                 output = self.classifier(features)
#      89                 return output
#      90
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/dropout.py in forward(self, input)
#      51
#      52     def forward(self, input):
# ---> 53         return F.dropout(input, self.p, self.training, self.inplace)
#      54
#      55
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in dropout(input, p, training, inplace)
#     550
#     551 def dropout(input, p=0.5, training=False, inplace=False):
# --> 552     return _functions.dropout.Dropout.apply(input, p, training, inplace)
#     553
#     554
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/_functions/dropout.py in forward(cls, ctx, input, p, train, inplace)
#      38             ctx.noise.fill_(0)
#      39         else:
# ---> 40             ctx.noise.bernoulli_(1 - ctx.p).div_(1 - ctx.p)
#      41         ctx.noise = ctx.noise.expand_as(input)
#      42         output.mul_(ctx.noise)
#
# KeyboardInterrupt:

# %%
train.shape

# %%
### LOAD MODEL, TEST
nli_net.load_state_dict(torch.load(os.path.join("saved_model", "model_1")))

# %%
def test_onePair(s1, s2):
    nli_net.eval()
    
    s1_batch, s1_len = get_batch(s1, wv, default_wv)
    s2_batch, s2_len = get_batch(s2, wv, default_wv)
    s1_batch, s2_batch = Variable(s1_batch.cuda()), Variable(s2_batch.cuda())

    # model forward
    output = nli_net((s1_batch, s1_len), (s2_batch, s2_len))
    pred = output.data.max(1)[1]
    return pred.item()

# %%
# test_vec1 = ["苏宁 易 购 所 出售 的 商品 均 为 正品 行货 均 来自 正规 渠道 带 正规 机 打 发票 享受 国家 三 包 服务 质量 和 售后 服务 与 门店 完全 相同 请您 放心 选购"]
# test_vec2 = [ "苏宁 易 购 所 出售 的 商品 均 为 正品 行货 请您 放心 选购"]
# test_vec3 = ["有 统一 的 全 国 售后 服务 正品 质量 保证"]
# test_vec4 = ["所有 货物 都 是 正品 请 安心 购买"]
# test_vec5 = ["正规 发票 服务 完全 相同 放心 享受 服务"]

# %%
# ind = 30
# s1 = test['s1'][ind]
# s2 = test['s2'][ind]
# label = test['label'][ind]
# print(s1)
# print(s2)
# print(label)
s1 = "空调 昨天 已 送 到 了，什么 时候 来 安装 啊"
s2 = "什么时候 上门 安装"
print(test_onePair([s1], [s2]))
# Out:
# 2

# %%
# from gensim.models import Word2Vec
# from gensim.models import KeyedVectors
# wv = KeyedVectors.load_word2vec_format("allQuestions.model.bin", binary=True)

# %%
# vector_dim = 300
# embedding_matrix = np.zeros((len(wv.vocab), vector_dim))
# avg = np.zeros((1, vector_dim))
# for i in range(len(wv.vocab)):
#     embedding_vector = wv[wv.index2word[i]]
#     if embedding_vector is not None:
#         embedding_matrix[i] = embedding_vector
#         avg += embedding_vector
# avg /= len(wv.vocab)

# %%
kb_answer.code.plot()
# Out:
# /home/tingchunyeh/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## EDA

# %%
kb_answer = pd.read_csv(data_path+'/kb_question.csv').dropna(axis=1)
# ha_answer = pd.read_csv(data_path+'/qa_history.csv').dropna(subset=['参考答案分词', '坐席回复分词', '坐席回复'], how='any')

# %%
kb_answer['答案长度'] = kb_answer['默认答案'].apply(lambda x: len(x))
kb_answer['分词长度'] = kb_answer['答案分词'].apply(lambda x: len(x.split()))
ha_answer['参考答案长度'] = ha_answer['参考答案'].apply(lambda x: len(x))
ha_answer['参考答案分词长度'] = ha_answer['参考答案分词'].apply(lambda x: len(x.split()))
ha_answer['坐席回复长度'] = ha_answer['坐席回复'].apply(lambda x: len(x))
ha_answer['坐席回复分词长度'] = ha_answer['坐席回复分词'].apply(lambda x: len(x.split()))

# %%
display(ha_answer.sample(n=100).iloc[:, :4])
# Out:
#                                                                       用户问题  \
# 23026                                                                   谢谢
# 2816                                                           就是苏宁支付我密码不对
# 1314                                                          这个奶粉日期是什么时候的
# 3542                                                           节能补贴在哪里上传图片
# 10929                                                                 没关系，
# 92                                                              上门维修有统一价格么
# 8819                                                                    谢谢
# 15530                                                               没有了，谢谢
# 13752                                                                   谢谢
# 23048                                                              那空调安装费呢
# 13164                                                  不然这样我会认为你给我的是不是翻新机。
# 5179                                                           可以和别的易购券叠加吗
# 18354                                                                 订单取消
# 2136                                                                     在
# 2535                                                                   谢谢了
# 872                                                               可以，请发我邮箱
# 13803                                                   你好在线购买可以去实体店直接提货是吗
# 11328                                                         哎今天买今天下午能到吗？
# 20718                                                             能改成送货上门吗
# 830                                                           从我们这里的店里发的货吗
# 19902                                                               好的，谢谢了
# 4322                                                                    谢了
# 8213                                                                 好的，谢谢
# 1542                                                                好的，谢谢你
# 4318                                                                    好的
# 13004                                                                差价怎么补
# 20731                                                              就这样吧，谢谢
# 12704                                                                   谢谢
# 4172                                                                   不要券
# 20233                                                           一般送货范围是哪些呀
# 13789                                                                 你这服务
# 5263                                                              可以自行安装吗？
# 4289                                                             电子发票保修能用吗
# 18419                                                         村子可以送货上门，安装吗
# 7281                                                       这款没水要加水的，不加水要紧吗
# 4067                                                               这个安装收费吗
# 4076                                                              为啥不能货到付款
# 8412                                                              好的 谢谢啦！！
# 12468                                                                   好的
# 954                                                                     谢谢
# 2825                                                                    谢谢
# 18982                                                    你好，我想改下22日送货，可以吗？
# 15389                                                                   谢了
# 10026                                                                   谢谢
# 12569                                                                 换货呢？
# 21336                                                亲，8PLUS 256G只有金色有货啊？？
# 20743                                                                好的，谢谢
# 456                                                           充话费算入购物天数的不？
# 8307                                                         买一个P20有什么东西送？
# 2388                                                     任性付现在开不了，因为以前号码换了
# 23751                                                                谢谢你，拜
# 6221                                                                    是的
# 21584                                                                   谢谢
# 13603                      因为京东是赠品直接会到购物车，你们的购物车没有赠品出来，所以我才和你们售后确认，居然还这种态度
# 22726                                                          空调安装送货是一起吗？
# 6096                                                            裸机是全新未拆封的吧
# 16552                                                        不可以到这边苏宁易购修吗？
# 8270                                                                从哪里发货的
# 1292                                                                  保价规则
# 23763  ￥380 [全额抵用] ￥52.6[全额抵用] 我账户里有两张抵用券 问1 这是不是贵就赔自动补偿的？ 问2 张对应的是哪两个订单号？
# 23776                                                                  没有了
# 15518                                                               用才几天就坏
# 23350                                                         所以。。麻烦了。不好意思
# 10094                                                            没有看到退款服务嘛
# 14036                                                                 免费的吗
# 3968                                                                    谢谢
# 5677                                                         云南昆明西山区海口镇能到吗
# 21672                                                                   好的
# 19787                                                           支持银行转帐付款么？
# 15376                                                                好的，谢谢
# 13145                                                                   谢谢
# 11743                                          是这样的，我之前有张20块钱的优惠券过期了，帮我搞一下
# 6295                                                      您好，下单后仓库24小时发货出库
# 6647                                                     实体店和网上自营店的机器是一样的嘛
# 4603                                    我买那么多就不能把优惠给我吗？我还有几个预付的呢，也没提示时间限制啊
# 14824                                                                   谢谢
# 993                                                            我定的东西如何改运费呀
# 1947              https://m.suning.com/product/0000000000/10550225388.html
# 8002                                                                 好的谢谢了
# 6348                                                               这个怎么处理呢
# 5163                                                                    谢谢
# 15147                                                                 带发票吗
# 8145                                                             易付宝如何注销呢？
# 7390                                                                  我要投诉
# 1185                                                              网店，门店自提的
# 22196                                                   可是说明书包装盒都不在了，也可以吗？
# 306                                                      我如果退了，可能就买不到这个价格了
# 10948                                                        我在哪里查看取消的订单好的
# 17057                                                       还有我门店的会员卡忘记密码了
# 9593                                                                   为什么
# 13057                                                                   辛苦
# 19895                                                          你好付款后什么时候发货
# 19912                                                           本地区暂不销售啥意思
# 16848                                                                 对的谢谢
# 18920                                                         好的，亲亲，谢谢，麻烦了
# 12585                                                        怎么支付时不能选择支付宝？
# 14820                                                                  谢谢啦
# 12166                                                              包装里没有发票
# 4485                                                                    好吧
# 12401                                                        我参加的活动什么时候发货？
#
#                                                                                                       参考答案  \
# 23026                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 2816   电脑端可直接https://pay.suning.com/epp-epw/security/security-manage!initSecurityCenter.action点击这里重置支付密...
# 1314        由于进货批次不同生产地点不同，生产日期具体可以在包装上查询，不过您放心我司所售产品均在保质期内，部分临期的商品会在页面做临期提示，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 3542   补贴流程 1、在苏宁易购选购节能减排补贴商品，并支付(仅限北京地区)； 2、支付后一小时内，需上传身份证件扫描件(仅限北京户口)； 3、苏宁代消费者将相关身份证件信息提交至政府系统进行审核，如...
# 10929                                                                                         好的，您真是宽容大度呢！
# 92     保内/延保期内维修：机器本身故障问题，免费维修；保外维修/人为原因导致机器故障：收费维修。实际收费标准需工程师上门判断故障类型后再确定。可以$url=http://help.suning.co...
# 8819                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 15530                                                                                        不客气，亲爱的，应该的哈！
# 13752                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23048  苏宁安装新机安装免人工费，工程师服务前向用户出示收费价目表/明细，并提前做好预算取得顾客同意，收费不得高于页面标准http://help.suning.com/page/id-478.htm，...
# 13164   苏宁自营商品均来自正规渠道，属正品行货。凡在苏宁易购购买苏宁自营商品，将与亲临苏宁门店选购的商品一样，开具发票（海外代购商品除外），并享受相同的质量保证，入驻商家也是经过严格审核的，请您放心选购~
# 5179                                   无敌券和云券一个订单可自身叠加多张使用。易券不支持自身叠加使用。无敌券，云券和易券可以相互叠加使用，且需一次性使用，不可拆分，不找零~
# 18354  如确定取消可点击$url=https://res.m.suning.com/project/cart/orderList.html?tabType=b2c&status=MB_C&index=...
# 2136                                                                                Hi~ o(*￣▽￣*)ブ，很乐意为您效劳！
# 2535                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 872      电子发票需要在确认收货后48小时内开具，点击我的订单-查看详情，在商品信息下，点击“发票下载”就可以查询下载啦，若还未生成下载按钮，建议您耐心等待。电子发票打开失败的用户，可使用PDF软件打开。
# 13803  下单时在配送方式里选择自提，可选择门店自提或者自提柜自提，自提时间可参考下单时选择的指定配送时间（我的订单-物流查询），下单后需收到短信验证码再去对应自提点提货，商品在自提柜可保留3天，自提点...
# 11328  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 20718                                                          很抱歉，已经提交的订单和已支付订单无法修改配送方式，我们会尽快给您送达，请您耐心等待。
# 830                                           亲爱哒，苏宁发货商品会根据您收货地址自动选择就近的仓库发货的哦。非苏宁发货商品在购买页或物流信息查询里会显示发货地的呢。
# 19902                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 4322                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 8213                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 1542                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 4318                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 13004  http://assss.suning.com/assss-web/wap/sNWapPriceProtectedController/getWapPriceProtectedList_1_0...
# 20731                                                                                        不客气，亲爱的，应该的哈！
# 12704                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 4172                                                                       亲很抱歉，暂不支持现金贵就赔，苏宁以自营无敌券的形式返还给您。
# 20233                            【苏宁发货】商品，下单填写地址时能正常保存的就是在配送范围内的，且支持送货上门服务；非苏宁发货商品，建议联系购买页面上的在线客服确定下配送范围哟。
# 13789                                                              您消消气哈，有什么问题咱肯定竭尽全力为您解决的，不妨把您的问题告诉sunny。
# 5263                                                 亲亲，大家电建议您不要自行安装哦，若是自行安装导致的商品外观破损或者其他商品质量问题，这边售后是不负责的呢
# 4289                                          电子普通发票是税务机关认可的有效收付款凭证，其法律效力、基本用途及使用规定同纸质普通发票， 可用于报销入账、售后维权等。
# 18419                            【苏宁发货】商品，下单填写地址时能正常保存的就是在配送范围内的，且支持送货上门服务；非苏宁发货商品，建议联系购买页面上的在线客服确定下配送范围哟。
# 7281                        冰晶完全冰冻后能用4个小时。冰晶完全冷冻的时间是在零下5°以下冰冻２－４小时。冰晶盒在没有破裂的情况下是一直可以使用的。冰晶可重复使用。一般自带两块冰晶的哈
# 4067   您好，苏宁安装新机大部分品类安装免人工费，工程师服务前向用户出示收费价目表/明细，若涉及原配件之外的材料是按照收费标准，具体可参考商品详情页安装收费标准或$url=http://help.su...
# 4076   下单的时候保存详细的收货地址，在支付方式里面会显示是否支持货到付款的，如果不支持的话会提示您使用在线支付。选择货到付款的支付方式，您可以选择现金支付或者移动POS刷卡支付。点击链接http:/...
# 8412                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12468                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 954                                                         不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 2825                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 18982  【苏宁发货】可以自主修改指定送达时间，在线支付最多延迟45天，货到付款最多延迟7天。您可$url=https://res.m.suning.com/project/cart/orderList...
# 15389                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 10026                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12569  您可“$url=https://assss.suning.com/assss-web/wap/servicefusion/goReturnChangeList_0.do&name=点击这里$进...
# 21336                                                您好，请输入您所在的城市（市），部分地区情况有所不同。（如果您不是要查询商品的库存或价格，请回复“不是”）
# 20743                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 456    购物天数是按自然日（00:00:00-23:59:59）计算，产生至少1笔单件商品实际付款金额在10元以上的订单且该订单完成支付和收货，（实际支付金额不包括券、云钻、运费在内），则该日计为一个...
# 8307   有无赠品以及赠品详情以下单时网页描述为准，部分赠品随主商品一同生成订单了则是随主商品一起寄送，部分赠品是“好评晒单”后单独寄出，详细规则以购买商品页面活动介绍为准（需收货45天内好评晒单，超时...
# 2388   很抱歉，任性付与任性贷产品是互联网金融产品，本次申请失败可能源于您的网购信息或其他第三方信息无法支持我们做出判断，您可以有以下选择：①登录苏宁易购网站购买心仪商品；②保持良好个人信用。最好间隔...
# 23751                                                                              感谢您对苏宁易购的支持，祝您生活愉快，再见~-
# 6221                                                                                                   好嘞！
# 21584                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 13603                                     赠品送货都是以页面描述为准的，如您符合活动规则，超期未收到赠品，咨询人工客服为您查询；如果您购买第三方商家商品需要联系掌柜的哟！
# 22726                                     购买页面带有【送装一体】标识的商品，配送员送上门后为您提供安装服务。请以页面展示为准。（目前只有电视和热水器享受送装一体的服务）
# 6096                                                          裸机是指没有绑定任何合约购买的手机，不是只有手机，自带充电器是有的，具体以包装清单为准。
# 16552  苏宁承诺：所有商品凭发票均可以享受生产厂家的全国联保服务或指定服务商联保服务。您可以[link url=http://assss.suning.com/assss-web/pc/service...
# 8270                                                【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 1292   您在苏宁易购购买自营商品收货前及收货次日起七天内，如果发现同一城市同一销售渠道的商品售价低于您购买时的价格，您可提交七天贵就赔申请，苏宁将依据本政策将差价以自营无敌券的形式返还给您。电脑端：点...
# 23763                                   您好，在订单结算页面点击“使用优惠券”勾选可使用的券（如果无法勾选，证明这个券不适用此活动哦），具体原因可点击该券查看具体使用规则。
# 23776                                                              尊敬的客户，感谢您对苏宁金融产品的支持！关于这个问题我这边查看下，马上回复您哦
# 15518  苏宁承诺：所有商品凭发票均可以享受生产厂家的全国联保服务或指定服务商联保服务。您可以[link url=http://assss.suning.com/assss-web/pc/service...
# 23350                                                                                        不客气，亲爱的，应该的哈！
# 10094  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 14036                                                可以点击该网址查询https://help.suning.com/page/search-554.htm.
# 3968                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 5677                    由苏宁发货的商品，下单填写地址时能正常保存的就是在配送范围内的，并且支持送货上门入户的哈（在包邮范围内不收取上楼费），非苏宁发货商品，以第三方快递公司服务范围为准哦
# 21672                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19787  苏宁支付方式目前有任性付、门店支付、易付宝支付、网银支付、快捷支付、分期付款、支付宝支付、微信支付、企业汇款、货到付款、和扫码支付，找人代付。$url=http://res.suning.cn...
# 15376                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 13145                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 11743                                                                   优惠券都是有使用时间限制的，并且过期不支持延期，建议在有效期内使用。
# 6295                                                【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 6647                        您好，苏宁门店和易购同一型号商品基础价格是一致的，但是部分活动商品及特价促销商品会存在价格差异，具体可以预约门店导购咨询哦，APP端点击首页身边的苏宁即可。
# 4603                   您好，所有的优惠活动可以关注易购主页或商品购买页的【促销活动】栏，会有领券、满减、赠品等活动，具体活动以页面为准，优惠后的价格以支付时为准，无法手动给您直接调价的哈。
# 14824                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 993    【苏宁发货】商品单笔订单实际支付满86元（V4会员满76元）免基础运费，自提免运费。订单配送方式、收货地址、商品类型、商品重量均会影响运费计算。电脑端https://help.suning.c...
# 1947                                                                                 您好，请问关于这款商品，有什么可以帮到您？
# 8002                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 6348   http://assss.suning.com/assss-web/wap/sNWapPriceProtectedController/getWapPriceProtectedList_1_0...
# 5163                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 15147  苏宁自营商品提交订单时选择需要开具的发票类型，并填写发票抬头信息即可。发票金额为您购买商品实际的付款金额（赠品订单、厂送10元以下订单不开发票），http://res.suning.cn/pr...
# 8145   亲确认要注销吗？可在苏宁金融APP里点击“我的”，点击右上角齿轮“设置”，“账户安全中心”-“账户注销”。注销账户将会失去当前已拥有的部分权益，请谨慎操作；如果仍要注销，可点击“仍要注销”按钮...
# 7390                                                       确实很抱歉给您带来不便，为了更好更快速地解决您的问题，点击转人工联系客服MM为您处理#转人工#
# 1185   下单时在配送方式里选择自提，可选择门店自提或者自提柜自提，自提时间可参考下单时选择的指定配送时间（我的订单-物流查询），下单后需收到短信验证码再去对应自提点提货，商品在自提柜可保留3天，自提点...
# 22196                                                                                 亲亲别着急，MM马上帮您核实，请您稍等！
# 306    http://assss.suning.com/assss-web/wap/sNWapPriceProtectedController/getWapPriceProtectedList_1_0...
# 10948  已经删除的订单可在订单回收站查看到该订单信息，可以http://order.suning.com/order/recycleList.do点击这里进入订单回收站还原订单，也可将该订单永久删除，...
# 17057                                 门店会员卡密码一般是在您办卡时系统通过短信形式发送至您的手机上的，如您忘记密码可以携带身份证和会员卡前往全国任意一家苏宁门店办理修改密码
# 9593           1.是否是参加活动，活动商品已经结束导致支付不了；2.超了支付时间或商品无货会导致订单无法支付，建议重新下单或购买其他商品；3.同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 13057                                                                                        不客气，亲爱的，应该的哈！
# 19895  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。http://order.suning....
# 19912                                                     商品暂不销售或者暂无报价，可能是因为长期无货，也可能是因为商品无法配送到当地，可以选择其他的款。
# 16848                                                                                        不客气，亲爱的，应该的哈！
# 18920                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12585  微信上关注苏宁易购-苏宁购物-找你喜欢-搜索您需要的商品下单，下单后支付方式有微信支付。新人、V1、V2、V3会员在PC、APP和WAP三端可支持支付宝支付，V4会员暂时只支持手机网页版使用支...
# 14820                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12166  可以先进入订单中心，查看自己的发票类型， 普通发票一般是放于购物袋/纸箱内或者粘在包装上，还请您仔细找下，厂送发票需要点击确认收货后5-7工作日寄送，增值税发票是需要完成认证后5-7工作日寄送...
# 4485                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12401  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。$url=https://res.m.s...
#
#                                                                                                       坐席回复  \
# 23026                                                                                     不客气，亲爱哒，很高兴为您服务。
# 2816   电脑端可直接https://pay.suning.com/epp-epw/security/security-manage!initSecurityCenter.action点击这里重置支付密...
# 1314        由于进货批次不同生产地点不同，生产日期具体可以在包装上查询，不过您放心我司所售产品均在保质期内，部分临期的商品会在页面做临期提示，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 3542   补贴流程 1、在苏宁易购选购节能减排补贴商品，并支付(仅限北京地区)； 2、支付后一小时内，需上传身份证件扫描件(仅限北京户口)； 3、苏宁代消费者将相关身份证件信息提交至政府系统进行审核，如...
# 10929                                                                                            您真是宽容大度呢！
# 92     保内/延保期内维修：机器本身故障问题，免费维修；保外维修/人为原因导致机器故障：收费维修。实际收费标准需工程师上门判断故障类型后再确定。可以$url=http://help.suning.co...
# 8819                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 15530                                                                                    不客气 不客气，亲爱的，应该的哈！
# 13752                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23048  苏宁安装新机安装免人工费，工程师服务前向用户出示收费价目表/明细，并提前做好预算取得顾客同意，收费不得高于页面标准http://help.suning.com/page/id-478.htm，...
# 13164   苏宁自营商品均来自正规渠道，属正品行货。凡在苏宁易购购买苏宁自营商品，将与亲临苏宁门店选购的商品一样，开具发票（海外代购商品除外），并享受相同的质量保证，入驻商家也是经过严格审核的，请您放心选购~
# 5179                                   无敌券和云券一个订单可自身叠加多张使用。易券不支持自身叠加使用。无敌券，云券和易券可以相互叠加使用，且需一次性使用，不可拆分，不找零~
# 18354  如确定取消可点击$url=https://res.m.suning.com/project/cart/orderList.html?tabType=b2c&status=MB_C&index=...
# 2136                                                                                              很乐意为您效劳！
# 2535                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 872                         ，点击我的订单-查看详情，在商品信息下，点击“发票下载”就可以查询下载啦，若还未生成下载按钮，建议您耐心等待。电子发票打开失败的用户，可使用PDF软件打开。
# 13803  亲亲，下单时在配送方式里选择自提，可选择门店自提或者自提柜自提，自提时间可参考下单时选择的指定配送时间（我的订单-物流查询），下单后需收到短信验证码再去对应自提点提货，商品在自提柜可保留3天，...
# 11328  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 20718                                                          很抱歉，已经提交的订单和已支付订单无法修改配送方式，我们会尽快给您送达，请您耐心等待。
# 830                                                                          亲，苏宁发货商品会根据您收货地址自动选择就近的仓库发货的哦
# 19902                                                                         不客气，很高兴为您服务。感谢您对苏宁易购的支持，[鬼脸]
# 4322                                                                                      不客气，亲爱哒，很高兴为您服务。
# 8213                                                                         不客气，亲爱哒，很高兴为您服务。还有什么可以帮您？[鬼脸]
# 1542                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 4318                                                                                        嗯嗯亲爱哒，很高兴为您服务。
# 13004  http://assss.suning.com/assss-web/wap/sNWapPriceProtectedController/getWapPriceProtectedList_1_0...
# 20731                                                                                        不客气，亲爱的，应该的哈！
# 12704                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持
# 4172                                                                       亲很抱歉，暂不支持现金贵就赔，苏宁以自营无敌券的形式返还给您。
# 20233                                                                             不客气哦，如果您还有问题的话可以随时咨询[鬼脸]
# 13789                                                                              您消消气哈，有什么问题咱肯定竭尽全力为您解决的
# 5263                                                 亲亲，大家电建议您不要自行安装哦，若是自行安装导致的商品外观破损或者其他商品质量问题，这边售后是不负责的呢
# 4289                                          电子普通发票是税务机关认可的有效收付款凭证，其法律效力、基本用途及使用规定同纸质普通发票， 可用于报销入账、售后维权等。
# 18419                            【苏宁发货】商品，下单填写地址时能正常保存的就是在配送范围内的，且支持送货上门服务；非苏宁发货商品，建议联系购买页面上的在线客服确定下配送范围哟。
# 7281                                                                                                  可以的亲
# 4067   您好，苏宁安装新机大部分品类安装免人工费，工程师服务前向用户出示收费价目表/明细，若涉及原配件之外的材料是按照收费标准，具体可参考商品详情页安装收费标准或$url=http://help.su...
# 4076                                                 下单的时候保存详细的收货地址，在支付方式里面会显示是否支持货到付款的，如果不支持的话会提示您使用在线支付。
# 8412                                                                        感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12468                                                                       感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 954                                                        不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个好评哈。
# 2825                                                                                              不客气，亲爱哒，
# 18982  【苏宁发货】可以自主修改指定送达时间，在线支付最多延迟45天，货到付款最多延迟7天。您可$url=https://res.m.suning.com/project/cart/orderList...
# 15389                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持
# 10026                                                   不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。[飞吻]
# 12569  您可“$url=https://assss.suning.com/assss-web/wap/servicefusion/goReturnChangeList_0.do&name=点击这里$进...
# 21336                                                                                     您好，您给我 您所在的城市（市）
# 20743                                                   不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。[飞吻]
# 456    购物天数是按自然日（00:00:00-23:59:59）计算，产生至少1笔单件商品实际付款金额在10元以上的订单且该订单完成支付和收货，（实际支付金额不包括券、云钻、运费在内），则该日计为一个...
# 8307                                                                                 有无赠品以及赠品详情以下单时网页描述为准哈
# 2388   很抱歉，任性付与任性贷产品是互联网金融产品，本次申请失败可能源于您的网购信息或其他第三方信息无法支持我们做出判断，您可以有以下选择：①登录苏宁易购网站购买心仪商品；②保持良好个人信用。最好间隔...
# 23751                                                                              感谢您对苏宁易购的支持，祝您生活愉快，再见~-
# 6221                                                                                            好嘞！什么原因退的呢
# 21584                                                      不客气，，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。[鲜花]
# 13603                                     赠品送货都是以页面描述为准的，如您符合活动规则，超期未收到赠品，咨询人工客服为您查询；如果您购买第三方商家商品需要联系掌柜的哟！
# 22726                                     购买页面带有【送装一体】标识的商品，配送员送上门后为您提供安装服务。请以页面展示为准。（目前只有电视和热水器享受送装一体的服务）
# 6096                                                          裸机是指没有绑定任何合约购买的手机，不是只有手机，自带充电器是有的，具体以包装清单为准。
# 16552  您可以http://assss.suning.com/assss-web/pc/servicefusion/goReturnChangeList.do 自助预约维修退换货都是可以的。（提示：小...
# 8270                                                                                             这个是供应商发货的
# 1292   “七天贵就赔”，是指您在苏宁易购购买自营商品收货前及收货次日起七天内，如果发现同一城市同一销售渠道的商品售价低于您购买时的价格，您可提交七天贵就赔申请，苏宁将依据本政策将差价以自营无敌券的形式...
# 23763                                                                                               请您稍等一下
# 23776                                                     好的，亲亲，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 15518                                                                                            亲，稍等，帮您看看
# 23350                                                                                             不客气，应该的！
# 10094  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 14036                                                             双缸、波轮、滚筒、迷你、干衣机、洗干一体机\t海尔保修期整机1年，主要部件3年。
# 3968                                                                           谢谢亲亲 已经帮您上报反馈的了会在24小时内联系您的亲
# 5677               亲，由苏宁发货的商品，下单填写地址时能正常保存的就是在配送范围内的，并且支持送货上门入户的哈（在包邮范围内不收取上楼费），具体以您下单时填写详细地址为准。不报错就是正常能送的
# 21672                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19787  苏宁支付方式目前有任性付、门店支付、易付宝支付、网银支付、快捷支付、分期付款、支付宝支付、微信支付、企业汇款、货到付款、和扫码支付，找人代付。$url=http://res.suning.cn...
# 15376                                                                                     不客气，亲爱哒，很高兴为您服务。
# 13145                                                                                     不客气，亲爱哒，很高兴为您服务。
# 11743                                                                   优惠券都是有使用时间限制的，并且过期不支持延期，建议在有效期内使用。
# 6295                                                                                         您好 会催促仓库尽快作业哈
# 6647                                                                                           您好，是一样的哦，亲，
# 4603                   您好，所有的优惠活动可以关注易购主页或商品购买页的【促销活动】栏，会有领券、满减、赠品等活动，具体活动以页面为准，优惠后的价格以支付时为准，无法手动给您直接调价的哈。
# 14824                                                                                     不客气，亲爱哒，很高兴为您服务。
# 993    【苏宁发货】商品单笔订单实际支付满86元（V4会员满76元）免基础运费，自提免运费。订单配送方式、收货地址、商品类型、商品重量均会影响运费计算。电脑端https://help.suning.c...
# 1947                                                                            您好，请问关于这款商品，有什么可以帮到您？亲亲 您好
# 8002                                                                很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 6348   http://assss.suning.com/assss-web/wap/sNWapPriceProtectedController/getWapPriceProtectedList_1_0...
# 5163                                                                                      不客气，亲爱哒，很高兴为您服务。
# 15147  苏宁自营商品提交订单时选择需要开具的发票类型，并填写发票抬头信息即可。发票金额为您购买商品实际的付款金额，http://res.suning.cn/project/sucas/wap/mySe...
# 8145   可在苏宁金融APP里点击“我的”，点击右上角齿轮“设置”，“账户安全中心”-“账户注销”。注销账户将会失去当前已拥有的部分权益，请谨慎操作；如果仍要注销，可点击“仍要注销”按钮。建议先解除和易...
# 7390                                                                                 确实很抱歉给您带来不便，小妹在为您查看了亲
# 1185                                                                                          亲 建议您自行邮寄 运费
# 22196                                                                                   亲亲别着急，马上帮您核实，请您稍等！
# 306    http://assss.suning.com/assss-web/wap/sNWapPriceProtectedController/getWapPriceProtectedList_1_0...
# 10948  已经删除的订单可在订单回收站查看到该订单信息，可以http://order.suning.com/order/recycleList.do点击这里进入订单回收站还原订单，也可将该订单永久删除，...
# 17057                                 门店会员卡密码一般是在您办卡时系统通过短信形式发送至您的手机上的，如您忘记密码可以携带身份证和会员卡前往全国任意一家苏宁门店办理修改密码
# 9593                                                                                         是的  现在理解您的心情的
# 13057                                                                                            不客气，应该的哈！
# 19895  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。http://order.suning....
# 19912                                                     商品暂不销售或者暂无报价，可能是因为长期无货，也可能是因为商品无法配送到当地，可以选择其他的款。
# 16848                                                                                                 您客气了
# 18920                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12585  微信上关注苏宁易购-苏宁购物-找你喜欢-搜索您需要的商品下单，下单后支付方式有微信支付。新人、V1、V2、V3会员在PC、APP和WAP三端可支持支付宝支付，V4会员暂时只支持手机网页版使用支...
# 14820                                                               很高兴为您服务 感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12166  可以先进入订单中心，查看自己的发票类型， 普通发票一般是放于购物袋/纸箱内或者粘在包装上，还请您仔细找下，厂送发票需要点击确认收货后5-7工作日寄送，增值税发票是需要完成认证后5-7工作日寄送...
# 4485                                                            很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。[口水]
# 12401  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。$url=https://res.m.s...
#
#         回复类型
# 23026  编辑后采用
# 2816   编辑后采用
# 1314   编辑后采用
# 3542   编辑后采用
# 10929  编辑后采用
# 92     编辑后采用
# 8819   编辑后采用
# 15530  编辑后采用
# 13752  编辑后采用
# 23048  编辑后采用
# 13164  编辑后采用
# 5179   编辑后采用
# 18354  编辑后采用
# 2136   编辑后采用
# 2535   编辑后采用
# 872    编辑后采用
# 13803  编辑后采用
# 11328  编辑后采用
# 20718  编辑后采用
# 830    编辑后采用
# 19902  编辑后采用
# 4322   编辑后采用
# 8213   编辑后采用
# 1542   编辑后采用
# 4318   编辑后采用
# 13004  编辑后采用
# 20731  编辑后采用
# 12704  编辑后采用
# 4172   编辑后采用
# 20233  编辑后采用
# 13789  编辑后采用
# 5263   编辑后采用
# 4289   编辑后采用
# 18419  编辑后采用
# 7281   编辑后采用
# 4067   编辑后采用
# 4076   编辑后采用
# 8412   编辑后采用
# 12468  编辑后采用
# 954    编辑后采用
# 2825   编辑后采用
# 18982  编辑后采用
# 15389  编辑后采用
# 10026  编辑后采用
# 12569  编辑后采用
# 21336  编辑后采用
# 20743  编辑后采用
# 456    编辑后采用
# 8307   编辑后采用
# 2388   编辑后采用
# 23751  编辑后采用
# 6221   编辑后采用
# 21584  编辑后采用
# 13603  编辑后采用
# 22726  编辑后采用
# 6096   编辑后采用
# 16552  编辑后采用
# 8270   编辑后采用
# 1292   编辑后采用
# 23763  编辑后采用
# 23776  编辑后采用
# 15518  编辑后采用
# 23350  编辑后采用
# 10094  编辑后采用
# 14036  编辑后采用
# 3968   编辑后采用
# 5677   编辑后采用
# 21672  编辑后采用
# 19787  编辑后采用
# 15376  编辑后采用
# 13145  编辑后采用
# 11743  编辑后采用
# 6295   编辑后采用
# 6647   编辑后采用
# 4603   编辑后采用
# 14824  编辑后采用
# 993    编辑后采用
# 1947   编辑后采用
# 8002   编辑后采用
# 6348   编辑后采用
# 5163   编辑后采用
# 15147  编辑后采用
# 8145   编辑后采用
# 7390   编辑后采用
# 1185   编辑后采用
# 22196  编辑后采用
# 306    编辑后采用
# 10948  编辑后采用
# 17057  编辑后采用
# 9593   编辑后采用
# 13057  编辑后采用
# 19895  编辑后采用
# 19912  编辑后采用
# 16848  编辑后采用
# 18920  编辑后采用
# 12585  编辑后采用
# 14820  编辑后采用
# 12166  编辑后采用
# 4485   编辑后采用
# 12401  编辑后采用

# %%
display(ha_answer.describe())
# Out:
#              参考答案长度      参考答案分词长度        坐席回复长度      坐席回复分词长度
# count  23845.000000  23845.000000  23845.000000  23845.000000
# mean      75.444873     34.646635     50.279975     23.350681
# std       58.774332     21.675212     53.794340     21.093126
# min        3.000000      1.000000      1.000000      1.000000
# 25%       46.000000     26.000000     15.000000      7.000000
# 50%       46.000000     26.000000     28.000000     15.000000
# 75%       99.000000     49.000000     64.000000     32.000000
# max      593.000000    310.000000    449.000000    244.000000

# %%
# display(kb_answer.sample(n=100))

# %%
# display(kb_answer.describe())

# %%
ha_answer_99 = ha_answer[ (ha_answer['参考答案分词长度']<100) & (ha_answer['坐席回复分词长度']<100)]

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,1,1)
plt.title('参考答案分词长度直方图', fontsize=14)
ax1 = ha_answer_99['参考答案分词长度'].plot(kind='hist', bins=50)
plt.xlabel('# tokens', fontsize=14)
plt.ylabel('Count', fontsize=14)

plt.subplot(2,1,2)
plt.title('坐席回复分词长度直方图', fontsize=14)
ax2 = ha_answer_99['坐席回复分词长度'].plot(kind='hist', bins=50)
plt.xlabel("# tokens", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4792305b558d> in <module>()
#       2 plt.subplot(2,1,1)
#       3 plt.title('参考答案分词长度直方图', fontsize=14)
# ----> 4 ax1 = ha_answer_99['参考答案分词长度'].plot(kind='hist', bins=50)
#       5 plt.xlabel('# tokens', fontsize=14)
#       6 plt.ylabel('Count', fontsize=14)
#
# NameError: name 'ha_answer_99' is not defined
# /home/tingchunyeh/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# 编辑后采用的答案长度明显比标准答案短

# %%
ha_answer_99['diff'] = ha_answer_99.loc[:,'参考答案分词长度']-ha_answer_99.loc[:,'坐席回复分词长度']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(12,6))
plt.title("分词長度差(坐席回复與参考答案)", fontsize=14)
ax1 = ha_answer_99['diff'].plot(kind='hist', bins=50)
plt.xlabel("# tokens", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.show()

# %%
ha_answer_diff20 = ha_answer_99[ (ha_answer_99['diff']>15) ][['用户问题', '参考答案', '坐席回复', '参考答案分词', '坐席回复分词']]

# %%
import re
pattern = re.compile('.*(谢谢)+.*')
def remove_thanks(x):
    res = pattern.search(x)
    return x if not res else None
temp = ha_answer_diff20['用户问题'].apply(lambda x: remove_thanks(x))
ha_answer_diff20 = ha_answer_diff20[~temp.isnull()]

# %%
display(ha_answer_diff20[['用户问题', '参考答案', '坐席回复']])
# Out:
#                                                                       用户问题                                                                                                 参考答案  \
# 3                                                                     有质保吗                          您好，  因商品生产批次较多，因商品生产批次较多，暂无法确定您购买商品的生产日期，不过请您放心，苏宁所卖商品均按照国家要求的保质期管理规范进行操作的。
# 4                                                       货到付款的订单能不能修改成在线支付？  下单的时候保存详细的收货地址，在支付方式里面会显示是否支持货到付款的，如果不支持的话会提示您使用在线支付。选择货到付款的支付方式，您可以选择现金支付或者移动POS刷卡支付。点击链接http:/...
# 8                                                         空调到了不满意可以无条件退货的吧  1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...
# 18                                                                      好吧                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 20                                                                  我还是抢不到                                             网站不提供价格、库存保护，因工厂调价、促销结束、抢购等造成的价格、库存变化以付款时为准。给您造成不便，敬请谅解！
# 21                                                         我在苏宁总部，明天可以送到吗？  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。http://order.suning....
# 31                                                        为什么我没有看到有免运费的选项啊  1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...
# 33                                                        你们是不是还支持7天无理由退货？  页面标注的符合7天无理由退货，商品完好的情况下可办理，具体可点击$url=https://assss.suning.com/assss-web/wap/servicefusion/goRetu...
# 40                                                        我买了2副Beats的蓝牙耳机了  煲耳机刚开始用轻柔一些的音乐，在较低音量下让耳机先舒缓10-30小时，然后用普通的音乐(摇滚、舞曲除外)在中等音量状态煲100-200小时。这时你听着高音不刺耳了，变得圆润自然，中音温暖亲切，...
# 46                                                                  买别的就可以  待支付的订单若需要修改支付方式，电脑端点击https://order.suning.com/order/orderList.do?transStatus=waitPay 手机端点击我的易购-待...
# 54                                                             大王 卡是免费赠送的吗             清洗服务需要费用的哦，实际收费标准需清洁师上门判断清洗类型确定后为准的，可以参考http://help.suning.com/page/id-535.htm，请问您需要预约吗？
# 56                                                                不是正品我找你的                                     苏宁易购所出售的商品均为正品行货，均来自正规渠道，带正规机打发票，享受国家三包服务，质量和售后服务与门店完全相同，请您放心选购。
# 64                                                               不能用发什么优惠卷  您可以在订单结算页面点击“使用优惠券”勾选可使用的券（如果无法勾选，证明这个券不适用此活动），在不可用券一栏可以查询具体不可使用原因。各类券的使用规则您可以$url=http://help.s...
# 65                                                            空调一般是哪里配送过来的                                               【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 66                                                         我下单的哪款可以配送上门安装吗                            【苏宁发货】商品，下单填写地址时能正常保存的就是在配送范围内的，且支持送货上门服务；非苏宁发货商品，建议联系购买页面上的在线客服确定下配送范围哟。
# 76                                                                就是下载不了软件  商品详情中会有系统的相关介绍，海信、创维、康佳、长虹、TCL是安卓定制系统兼容安卓的，三星、LG、创维是厂家研发的系统；智能电视有操作系统，只能在应用平台中下载软件！先锋智能电视也是不支持下载...
# 77                                                                   怎么更改？  发票内容为您所购买的商品明细，发票金额为所购商品实际支付金额（不含礼品卡、优惠券、云钻等支付部分），并且无法进行修改。如果您需要更改发票抬头或税号，若刚下单或未发货建议取消订单重新下单，取消之...
# 95                                                             投诉到你们明天就过期了                                                      确实很抱歉给您带来不便，为了更好更快速地解决您的问题，点击转人工联系客服MM为您处理#转人工#
# 98                                                     我想咨询一下我为什么买空调没有领到云钻                           评价获得云钻会在是评价后24小时内到账，购物云钻需要订单支付完成24小时内将相应云钻返至您的账户，选择货到付款会有一定时间延迟，建议您选择在线支付。
# 118                                                                   还是不行                                               抱歉哦亲亲，给您带来不便，请您提供下两次以上维修凭证和第三次无法维修同一故障的故障证明单据哦我为您反馈申请。
# 120                                                                  好的多谢。                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 122                                                                从哪发货知道吗                                               【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 124                                         我的意思是 已经申请成功 在7天之内 发现又降价了 怎么办？  您在苏宁易购购买自营商品收货前及收货次日起七天内，如果发现同一城市同一销售渠道的商品售价低于您购买时的价格，您可提交七天贵就赔申请，苏宁将依据本政策将差价以自营无敌券的形式返还给您。点击链接h...
# 127                                                                  怎么操作呢  您好，分期付款您可以在下单结算界面选择“信用卡分期”，支付成功后，银行会一次性扣除总金额，后期每个月给银行还款分期的金额；或者您选择任性付分期，3/6/9/12期都是可以的哦（部分商品会有免息...
# 131                                                           核桃奶生产日期是几月的？       由于进货批次不同生产地点不同，生产日期具体可以在包装上查询，不过您放心我司所售产品均在保质期内，部分临期的商品会在页面做临期提示，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 138                                                                    买不了          1.是否是参加活动，活动商品已经结束导致支付不了；2.超了支付时间或商品无货会导致订单无法支付，建议重新下单或购买其他商品；3.同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 142                                                                说是11号送的  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 148                                                                      嗯                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 152                                                                易付宝怎么激活          电脑端自助修改：登录账户（非信任登录），点击立即使用认证，如果该实名认证信息非本人，点击页面“申请变更”，根据页面提示上传资料（身份证正反面，手持身份证照片），等待1个工作日内审核。
# 164                                                                  这是啥意思          1.是否是参加活动，活动商品已经结束导致支付不了；2.超了支付时间或商品无货会导致订单无法支付，建议重新下单或购买其他商品；3.同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 169                                                              为什么还是买不了呀          1.是否是参加活动，活动商品已经结束导致支付不了；2.超了支付时间或商品无货会导致订单无法支付，建议重新下单或购买其他商品；3.同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 176                                                             这个没有收费标准吗？  您好，苏宁安装新机大部分品类安装免人工费，工程师服务前向用户出示收费价目表/明细，若涉及原配件之外的材料是按照收费标准，具体可参考商品详情页安装收费标准或$url=http://help.su...
# 177                                                           安装费还有架子怎么收费的  您好，新机安装过程中，包装箱以外增加的材料、配件等是另计收费的！安装前工人会先为您做价格预算，收费时会出示价目表，请您放心！具体安装价格公示优先查看该商品的详情页，另外对于路程较远的地址可能会...
# 178                                                                    知道了                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 181                                                                不想消费者利益                                                      确实很抱歉给您带来不便，为了更好更快速地解决您的问题，点击转人工联系客服MM为您处理#转人工#
# 184                                                            什么时候能到我账号上？  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 187                                                  就是这个卷。 你们之前的客服还说没有不能返  领取的券都是即时到账的，返券建议看下商品页面促销栏是否有参加返券活动，具体返券规则以页面返券活动详情为准，符合返券的活动规则，会在下单支付后24小时内返到您的账户的，可以$url=https:...
# 196                                                            亲，无敌券有效期多久？       由于进货批次不同生产地点不同，生产日期具体可以在包装上查询，不过您放心我司所售产品均在保质期内，部分临期的商品会在页面做临期提示，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 198                                                       是确认订单页面吗，我看没有赠送呢  有无赠品以及赠品详情以下单时网页描述为准，部分赠品随主商品一同生成订单了则是随主商品一起寄送，部分赠品是“好评晒单”后单独寄出，详细规则以购买商品页面活动介绍为准（需收货45天内好评晒单，超时...
# 205                                                                  包装被拆过                                                 非安装类商品请务必在签收时当着快递小哥面现场开箱验机；安装类商品建议预约安装后，由安装人员上门开箱验机。
# 208                                                           我买的吸奶器包装被拆开过                                                 非安装类商品请务必在签收时当着快递小哥面现场开箱验机；安装类商品建议预约安装后，由安装人员上门开箱验机。
# 217                                                            不然我又要投诉三一五了                                                      确实很抱歉给您带来不便，为了更好更快速地解决您的问题，点击转人工联系客服MM为您处理#转人工#
# 220                                         你好，我有一个订单自提的，但是一直没去，如果明天去来得及吗？  下单时在配送方式里选择自提，可选择门店自提或者自提柜自提，自提时间可参考下单时选择的指定配送时间（我的订单-物流查询），下单后需收到短信验证码再去对应自提点提货，商品在自提柜可保留3天，自提点...
# 222                                                             你那个串号哪里找到的                                                        您在订单中心也能找到自提码哦，（温馨提示：收到短信通知后自提柜可保留3天，自提点7天的哈）
# 228                                                            如何评价你们苏宁易购、  您可以点击我的易购-待评价-已评价 查看您的评价，一般评价后商品评论页不会立即显示，系统是会进行审核（48小时内审核完成）后才会展示在商品的评价页面的哦~ （温馨提示：如果评价中涉及广告字眼、...
# 231                                                       如果今天下单的话，什么时候能收到  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 235                                                        苏宁支付随机立减100什么意思  绑定的银行卡首次支付，在您提交订单支付时会有提示显示减价的。任性付支付等立减。立减金额随机最高100元最低0元（立减0元的说明此次优惠没有获得优惠）。任性付还有一种立减的优惠是满多少减多少，只...
# 238                                                                  我是真服了                                                               您就是上帝！------这是个哲学三联问啊！我是谁？我从哪里来？我将去哪里？
# 247                                                             现在买什么时候能安装  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。http://order.suning....
# 265                                                                   怎么退？  1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...
# ...                                                                    ...                                                                                                  ...
# 23531                                                      但是，你们现在又不会马上退款啊  您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账，您可以 [link url=http://assss.suning.c...
# 23545                                                                   好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23561                                                                我付钱了吗                                                                    您可以前往订单中心查看订单此时的状态，也可以查询银行卡的交易记录。
# 23576                                                             那我去申请换货吗  实际收货日期的次日起7天内可以申请退货（部分已激活商品不支持无理由退，无理由退货需保证商品附件包装完好不影响二次销售），有质量问题15天内可换货，[link url=http://assss....
# 23583                                                                 货到付款  下单的时候保存详细的收货地址，在支付方式里面会显示是否支持货到付款的,如果不支持的话会提示您使用在线支付。选择货到付款的支付方式，您可以选择现金支付或者移动POS刷卡支付。点击链接http:/...
# 23584                                                            电了发票可以报销吗  苏宁自营商品提供的普通发票均为正规机打卷式发票。需下单选择普通发票，苏宁配送订单普通发票与商品一起送达，厂送订单发票会在您点击确认收货后5-7工作日单独给您寄送，建议耐心等待。商家商品建议联系...
# 23587                                                      就是开通超级会员，返云钻的问题  SUPER会员2%云钻返还上限只有50000云钻哦，超出上限则不会返哦同时有一部分商品是不支持2%云钻返还的，您仔细看一下哦。 详情请看规则：https://help.suning.com/p...
# 23603                                                         绑定的你们苏宁微信公众号                                                                您可以点击我的易购-设置-安全设置-关联账号进行绑定或者解绑微信、QQ账号
# 23619                                              我也是按着这个订单重新购买的为什么就没有赠品？  有无赠品以及赠品详情以下单时网页描述为准，部分赠品随主商品一同生成订单了则是随主商品一起寄送，部分赠品是“好评晒单”后单独寄出，详细规则以购买商品页面活动介绍为准（需收货45天内好评晒单，超时...
# 23622                                                    首页里没找到可以解绑银行卡的内容啊                          苏宁金融APP，首页-银行卡可直接添加银行卡；如需解绑，同样在首页-银行卡-选择需要解绑的银行卡-管理-删除银行卡哦；（注：只能绑定账户本人的卡哦）。
# 23624                                                             等于是退款对吗？  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 23627                                                      这款滤芯24小时用，可以用多久  不同的滤芯更换周期是不同的，具体以产品售后这边回复为准哈。以下数据您可以参考下哈，这个数据根据顾客家中水质和使用情况，是有所增减的喔： Pp棉滤芯：3-6个月 活性炭滤芯：8-12个月 超滤膜...
# 23634                                                             明天保证送达是吧  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。电脑端http://order.suni...
# 23644                                                              哦，是免费安装  亲，苏宁安装新机大部分品类安装免人工费，安装过程中用到的包装箱之外的额外材料是收费的，http://help.suning.com/page/id-478.htm 这个是我司安装的价格表，您可...
# 23646                                                            亲 拼团是什么意思  选择乐拼购商品开团或者参团-付款成功-微信分享好友达到拼团人数-24小时达到拼团要求，拼团成功。手机端：https://c.m.suning.com/group_index.html?adTy...
# 23652                                                          我看出产日期是15年的       由于进货批次不同生产地点不同，生产日期具体可以在包装上查询，不过您放心我司所售产品均在保质期内，部分临期的商品会在页面做临期提示，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 23670                                                                   好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23674                                                                   好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23678                                                            电子发票开不了啦？  电子发票会在确认收货后48小时内开具，可以$url=http://res.m.suning.com/project/orderOther/dist/myInvoice.html#/&name=...
# 23682                                        我已经办理退货的苹果笔记本电脑，想要确认一下是不是可以退货  商品出现非人为质量问题以及支持无理由退换货的商品可自助申请退换货，自实际收货日期的次日起7天内退货，有质量问题15天内可换货，可[link url=http://assss.suning.co...
# 23695                                                           你们服务比京东差远了                                                        很抱歉给您带来困扰了 ，请问具体情况可以简单描述下.这可帮您联系下师傅和大区售后这边处理呢
# 23709                                                                包安装吗？  大家电提供安装服务，可在商品购买页查看安装服务方，如显示苏宁安装，配送完成后，会有当地网点跟您预约安装时间；如果显示供应商提供安装服务，需自行联系厂家进行预约安装，（商品页面--售后保障-售后...
# 23717                                                            感觉空调效果不好，  变频空调的压缩机能够在长期开启运转的情况下适度调温，如果室内不需要大量冷热时，空调就会以低频的状态运转，智能的恒定控温，而定频产品则需要在人为的情况下进行空调冷热的开关机调节。简单的说如果长时...
# 23724                                                        我这个钱能退到别的银行卡吗                                                               拼团有效期24小时内未邀请到足够人数参团即拼团失败，已付款原路退还支付账户。
# 23730                                                           别的型号的不可以了啊  实际收货日期的次日起7天内可以申请退货（部分已激活商品不支持无理由退，无理由退货需保证商品附件包装完好不影响二次销售），有质量问题15天内可换货，[link url=http://assss....
# 23733                                                                多久会退款  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 23739                                                              手机咋买不了啊  目前任性付购物贷款支持在苏宁门店以及苏宁易购使用。苏宁门店通过苏宁金融APP扫码支付，无需再次审核；苏宁易购需提交订单后选择任性付支付，其中虚拟商品、黄金、金银投资之外的所有商品（汽车除外），...
# 23741                                                        亲今天能知道我手机修好了吗  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 23745                                                                   好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23763  ￥380 [全额抵用] ￥52.6[全额抵用] 我账户里有两张抵用券 问1 这是不是贵就赔自动补偿的？ 问2 张对应的是哪两个订单号？                                   您好，在订单结算页面点击“使用优惠券”勾选可使用的券（如果无法勾选，证明这个券不适用此活动哦），具体原因可点击该券查看具体使用规则。
# 23770                                                         安装是需要购买什么东西吗  您好，苏宁安装新机大部分品类安装免人工费，工程师服务前向用户出示收费价目表/明细，若涉及原配件之外的材料是按照收费标准，具体可参考商品详情页安装收费标准或$url=http://help.su...
# 23778                                             为什么没有从绵阳发货呢？我家附近就有一家苏宁易购                                               【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 23781                                                           金质习酒啥时候有货？                                                您好，请输入您所在的城市（市），部分地区情况有所不同。（如果您不是要查询商品的库存或价格，请回复“不是”）
# 23783                                                                   好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23784                                                           我这个退款可以了么？  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 23789                                                 收到货时看外包装完整就可以签收了，是吗？      亲亲，在您签收前，请检查外包装是否有明显的挤压、损坏、受潮等情况；封条是否有损坏痕迹。如果是货到付款，需核对订单费用。小件/非安装类宝贝可当快递师傅面拆包验收的。如果发现任何问题，请拒收哦。
# 23794                                                         一单两个产品，只收到一个                                                       亲亲，如果错漏发、破损漏液了在线这边会为亲您尽快处理的。亲稍等下哦，我这边给您查看下订单先。
# 23801                                      哦哦，超过7天了，有质量问题也没法退了哈，超15天连换都不行哈  亲，您购买带有“30天包退，365天包换”标识的商品，若出现质量问题，自收货次日可30天内办理退货，365天内办理换货，电脑端http://assss.suning.com/assss-web...
# 23802                                                                嗯嗯 好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23806                                                               发什么快递？                如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递），厂家配送和商家商品用的是第三方快递，如：韵达、圆通、申通、中通、顺丰、EMS等
# 23809                                                     如果有质量问题你们承担寄回运费吗                                                    若是无理由退货需要您自行承担运费哦，质量问题退换货免取件费，商家退换货运费建议咨询购买页面商家客服
# 23811                                                       购机型号与收货型号有点不一致                                   您好，商品信息以页面展示为准哦，颜色规格等可以在页面选择也可进入商品页面点击“包装及参数”查询到该商品的详细功能及参数配件信息等。
# 23814                                                    6月24日收到的退货 什么时候退款  您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账，您可以 [link url=http://assss.suning.c...
# 23825                                                                 从哪发货                                               【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 23831                                                              可以货到付款吗  下单的时候保存详细的收货地址，在支付方式里面会显示是否支持货到付款的,如果不支持的话会提示您使用在线支付。选择货到付款的支付方式，您可以选择现金支付或者移动POS刷卡支付。点击链接http:/...
# 23834                 我使用微信支付的，至今未收到退款，绑定的银行卡我也查了这个月的记录，也没有收到退款，请问退款完成怎么说。  您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账，您可以 [link url=http://assss.suning.c...
# 23835                                                         我想问一下什么时候能退款  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 23836                                                        退款什么时间能到我的账上？  您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账，您可以 [link url=http://assss.suning.c...
# 23842                                                           售后和别的都一样是吧                                                 苏宁易购与天猫苏宁官方旗舰店只是销售平台不同，但均为苏宁销售并发货，有统一的全国售后服务，正品质量保证~
# 23845                                                             自提和配送的区别                自提、配送都是从中心仓发货的，时间上相差不大。在物流信息中会告知预计到货时间，到货之后会第一时间通知您。请以实际收货时间为准。（温馨提示：送货方式在订单提交后不支持修改）
#
#                                                                                                       坐席回复
# 3                                                                                                     亲 有的
# 4                                                          欠款-物流收 李小姐 15915717838 广州市南沙区全区南沙街珠电路中央郡5栋1003房
# 8      1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...
# 18                                                                                          亲，对给您带来的困扰表示抱歉
# 20                                                                                                    稍等的哈
# 21                                                                                                    可以的亲
# 31                                                                                        是的哈亲   上门取件免运费的呢
# 33                                                                                很高兴为您服务，请问还有其他问题可以帮到您的吗？
# 40                                                                                                     好的呢
# 46                                                           因产品服务升级，当前该业务暂停服务，开启时间待定，建议多多关注页面。给您带来不便，敬请谅解
# 54                                                                                          亲  有的赠送有的是增值业务
# 56                                                                                苏宁易购所出售的商品均为正品行货，请您放心选购。
# 64                                                                                         券的使用以下单勾选为准哦，亲，
# 65                                                                             【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货
# 66                                                               【苏宁发货】商品，下单填写地址时能正常保存的就是在配送范围内的，且支持送货上门服务
# 76                                                                                                      稍等
# 77                                                                                            您下单后我们这边帮您修改
# 95                                                                                      确实很抱歉给您带来不便，请您稍等一下
# 98                                                                                     亲 请稍等2分钟，这边立即帮您核实下哦
# 118                                                                                   抱歉哦亲亲，给您带来不便，我在帮您查询下
# 120                                                                                                不客气，亲爱哒
# 122                                                                           【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。
# 124                                                                                   7天之内  只要 符合条件就可以进行补差
# 127                                                                                                   [太阳]
# 131                                                                          请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 138                                                                            同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 142                                                      【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。
# 148                                                                                                    嗯呢亲
# 152                                                                                             您需要下载苏宁金融亲
# 164                                                                           .同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 169                                                                           .同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 176                                                                           安装费与人工费是免费的，如果用到额外材料需要收取材料费的
# 177                                                                           亲，麻烦提供一下您的订单号或者手机号我们这边帮您查询一下
# 178                                                                                         嗯嗯，亲爱哒，很高兴为您服务
# 181                                                                                           确实很抱歉给您带来不便，
# 184                                                                                 不好意思亲，这个是之前给您申请您当时还不需要
# 187                                                                                            亲这个已经给您申请了的
# 196                                                                                                  七天内有效
# 198    有无赠品以及赠品详情以下单时网页描述为准，部分赠品随主商品一同生成订单了则是随主商品一起寄送，部分赠品是“好评晒单”后单独寄出，详细规则以购买商品页面活动介绍为准（需收货45天内好评晒单，超时...
# 205                                                                                              亲亲如果不放心的话
# 208                                                                                                     亲亲
# 217                                                                                           确实很抱歉给您带来不便，
# 220                                                                                           商品在自提点可保留7天。
# 222                                                                                               您手机上可以看到
# 228                                                                                             亲亲可能到软件评价呢
# 231                                                    【苏宁发货】商品，下单页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。
# 235                                                                               苏宁在线支付。立减金额随机最高100元最低0元（
# 238                                                                                                  要退货是吗
# 247                                                                                  提交订单的页面有预计送达及安装的时间的哦亲
# 265                                                                                       您确认要退吗  小妹可以帮您操作
# ...                                                                                                    ...
# 23531                                                                                                  是的亲
# 23545                                                                                           亲，只能邮寄过去的呢
# 23561                                                                                                  付了亲
# 23576  是的亲 实际收货日期的次日起7天内可以申请退货，有质量问题15天内可换货，http://assss.suning.com/assss-web/pc/returnGoods/toAfterSal...
# 23583                  选择货到付款的支付方式，您可以选择现金支付或者移动POS刷卡支付。点击链接http://help.suning.com/page/search-763.htm查询详情
# 23584                                                                                        亲 苏宁开的都是正规发票哦
# 23587                                                                                          稍等马上为您查询处理~
# 23603                                                                                              是有什么问题吗
# 23619                                                                                               赠完为止的呢
# 23622                                                                苏宁金融APP，同样在首页-银行卡-选择需要解绑的银行卡-管理-删除银行卡
# 23624                                                                               亲   请问还有其他什么可以帮您的吗？^_^
# 23627                                                                                    亲，按您的这种情况，一般一年左右呢
# 23634                                                                                            预计是在明天送达的
# 23644                                                           亲，苏宁安装新机大部分品类安装免人工费，安装过程中用到的包装箱之外的额外材料是收费的
# 23646                                                     选择乐拼购商品开团或者参团-付款成功-微信分享好友达到拼团人数-24小时达到拼团要求，拼团成功。
# 23652                                                                   由于进货批次不同生产地点不同，不过您放心，我司所售产品均有售后保证的
# 23670                                                                                                不客气，亲
# 23674                                                                                                 [飞吻]
# 23678                                                                                         是的，电子发票生成比较慢
# 23682                                                                                          稍等，小妹查询 ^_^
# 23695                                                                                       很抱歉给您带来困扰了[太阳]
# 23709                                                                                            是我们苏宁安装的呢
# 23717                                                                您开空调设置温度 窗户之类的是需要关上后 一段时间后 温度才会慢慢降低的呢
# 23724                                                                                             别的银行卡吗亲？
# 23730                                                                                    换的话只能换同款的亲，换一模一样的
# 23733                                                                                             亲稍等帮您看一下
# 23739                                                                                               亲 系统火爆
# 23741                                                   亲，所谓“术业有专攻”，为了更好的给您解决问题，小妹帮您【对接】我们的专业客服给您处理，您看可以么？
# 23745                                                                                                亲亲稍等哦
# 23763                                                                                               请您稍等一下
# 23770                                                                                           三角阀、软管、接头等
# 23778                                                                         【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。
# 23781                                                                          您好，请输入您所在的城市（市），部分地区情况有所不同。
# 23783                                                                                      不客气，亲爱哒，很高兴为您服务
# 23784                                                                                        亲亲 麻烦提供一下订单号哦
# 23789                                            亲亲，在您签收前，请检查外包装是否有明显的挤压、损坏、受潮等情况；封条是否有损坏痕迹。如果发现任何问题，请拒收哦。
# 23794                                                                                              好的亲请稍等哦
# 23801                                                         亲，如果您购买带有“30天包退，365天包换”标识的商品，若出现质量问题，是可以退换的呢
# 23802                                                                                             那可能是有影响的
# 23806                                                        如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递）
# 23809                                                                                             质量问题免取件费
# 23811                                                                                        亲上面收货人的信息是您的么
# 23814                                        您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账。
# 23825                                                                          【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货
# 23831                                                下单的时候保存详细的收货地址，在支付方式里面会显示是否支持货到付款的,如果不支持的话会提示您使用在线支付。
# 23834                                                                             您好，退货完成后根据支付方式不同退款时间稍有不同
# 23835                         退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，请您注意查收哦~
# 23836                                         您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账
# 23842                                                                                    有统一的全国售后服务，正品质量保证
# 23845                                                         自提、配送都是从中心仓发货的，时间上相差不大。自提是发到门店您去提货  配送是送货上门的
#
# [5170 rows x 3 columns]

# %% [markdown]
# - 参考答案 编辑后回覆 比较
#
#
# "不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。"
# "不客气，亲爱哒"
#
# "苏宁易购所出售的商品均为正品行货，均来自正规渠道，带正规机打发票，享受国家三包服务，质量和售后服务与门店完全相同，请您放心选购。"
# "苏宁易购所出售的商品均为正品行货，请您放心选购。"
#
# "【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地"
# "【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货"
#
# "【苏宁发货】商品，下单填写地址时能正常保存的就是在配送范围内的，且支持送货上门服务；非苏宁发货商品，建议联系页面上的在线客服确定配送范围哟"
# "【苏宁发货】商品，下单填写地址时能正常保存的就是在配送范围内的，且支持送货上门服务"
#
# "苏宁易购与天猫苏宁官方旗舰店只是销售平台不同，但均为苏宁销售并发货，有统一的全国售后服务，正品质量保证~"
# "有统一的全国售后服务，正品质量保证"
#
#
# "自提、配送都是从中心仓发货的，时间上相差不大。在物流信息中会告知预计到货时间，到货之后会第一时间通知您。请以实际收货时间为准。（温馨提示：送货方式在订单提交后不支持修改）"
# "自提、配送都是从中心仓发货的，时间上相差不大。自提是发到门店您去提货 配送是送货上门的"

# %% [markdown]
# 参考答案囊括太多资讯, 回答用户特定问题时只需要其中一部分, 可以看到编辑后的答案通常是撷取一部分的标准答案
# 如果要对客服答案做评分, 以标准答案为基准做相似度比较可能不是很合适

# %% [markdown]
# word level
# 1. Jaccard
# 2. TF-IDF
# 3. word embedding avg
# 4. IDF word embedding avg / weighted word embedding avg
#
# Sentence level
# 6. sentence embedding - quick thought

# %% [markdown]
# ## TF-IDF + Cosine Simalarity

# %%
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
import pickle

# %%
count_vect = CountVectorizer(decode_error="ignore")
x = count_vect.fit_transform( pd.concat([ ha_answer_99['参考答案分词'], ha_answer_99['坐席回复'] ]) )
pickle.dump(count_vect.vocabulary_, open("feature.pkl","wb"))

# %%
transformer = TfidfTransformer()
loaded_vec = CountVectorizer(decode_error="ignore", vocabulary=pickle.load(open("feature.pkl", "rb")))

# tfidf = transformer.fit_transform(x)
# weight = tfidf.toarray()

# %%
test_vec1 = ["苏宁 易 购 所 出售 的 商品 均 为 正品 行货 均 来自 正规 渠道 带 正规 机 打 发票 享受 国家 三 包 服务 质量 和 售后 服务 与 门店 完全 相同 请您 放心 选购"]

# %%
test_vec2 = [ "苏宁 易 购 所 出售 的 商品 均 为 正品 行货 请您 放心 选购"]
test_vec3 = ["有 统一 的 全 国 售后 服务 正品 质量 保证"]
test_vec4 = ["所有 货物 都 是 正品 请 安心 购买"]
test_vec5 = ["正规 发票 服务 完全 相同 放心 享受 服务"]

# %%
tfidf1 = transformer.fit_transform(loaded_vec.fit_transform(test_vec1))
tfidf2 = transformer.fit_transform(loaded_vec.fit_transform(test_vec2))
tfidf3 = transformer.fit_transform(loaded_vec.fit_transform(test_vec3))
tfidf4 = transformer.fit_transform(loaded_vec.fit_transform(test_vec4))
tfidf5 = transformer.fit_transform(loaded_vec.fit_transform(test_vec5))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
print(cosine_similarity(tfidf1, tfidf2))
print(cosine_similarity(tfidf1, tfidf3))
print(cosine_similarity(tfidf1, tfidf4))
print(cosine_similarity(tfidf1, tfidf5))
# Out:
# [[0.5547002]]
# [[0.40032038]]
# [[0.0877058]]
# [[0.68219104]]

# %% [markdown]
# 关键字配对, 无法捕捉语义 -> n-gram

# %% [markdown]
# 同義詞 -> 替換
# 放心 - 安心
# 选购 - 购买
# 商品 - 货品
# 所有 - 全部

# %% [markdown]
# ## Avg word embedding

# %%
a = ha_answer_99['参考答案分词'].apply(lambda x: x.split()).values
b = ha_answer_99['坐席回复分词'].apply(lambda x: x.split()).values
c = a+b

# %%
from gensim.models import word2vec

# %%
model = word2vec.Word2Vec(c, size=100)  # 默认window=5

# %%
def avg_embedding(sentence):
    res = np.zeros(100)
    count = 0
    for w in sentence.split():
        if w not in model.wv.vocab: continue
        res = np.add(res, model.wv[w])
        count += 1
    if count==0: return 0
    return res/count

# %%
avg_embed1 = avg_embedding(test_vec1[0])
avg_embed2 = avg_embedding(test_vec2[0])
avg_embed3 = avg_embedding(test_vec3[0])
avg_embed4 = avg_embedding(test_vec4[0])
avg_embed5 = avg_embedding(test_vec5[0])

# %%
print(cosine_similarity([avg_embed1], [avg_embed2]))
print(cosine_similarity([avg_embed1], [avg_embed3]))
print(cosine_similarity([avg_embed1], [avg_embed4]))
print(cosine_similarity([avg_embed1], [avg_embed5]))
# Out:
# [[0.8380575]]
# [[0.69792483]]
# [[0.60340765]]
# [[0.86081633]]

# %%
from numpy import dot
from numpy.linalg import norm

# cos_sim = dot(a, b)/(norm(a)*norm(b))
def cos_sim(a, b):
    a = np.array(avg_embedding(a))
    b = np.array(avg_embedding(b))
    if (norm(a)*norm(b))==0: return 0
    return dot(a, b)/(norm(a)*norm(b))

ha_answer_99['score'] = ha_answer_99[['参考答案分词', '坐席回复分词']].apply(
                                         lambda x: float(cos_sim(x[0], x[1]) ) ,axis=1)

# %%
plt.figure(figsize=(14,6))
plt.title('similarity between 参考答案 and 坐席回复', fontsize=14 )
ha_answer_99['score'].plot(kind='hist')
plt.xlabel('similarity', fontsize=14 )
plt.ylabel('count', fontsize=14 )
plt.show()

# %%
display(ha_answer_99[(ha_answer_99['score']>0.8) & (ha_answer_99['diff']>10)][['用户问题', '参考答案', '坐席回复', 'score']].sample(n=100))
# Out:
#                                      用户问题                                                                                                 参考答案  \
# 2872                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 1115                             你们有原装耳机吗   电脑端：点击链接选择手机以及配件https://shouji.suning.com/。手机端：点击链接选择手机以及配件https://c.m.suning.com/03homePage.html。
# 18809                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 13791                           麻烦，发邮政不行吗                如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递），厂家配送和商家商品用的是第三方快递，如：韵达、圆通、申通、中通、顺丰、EMS等
# 18272                   我想买个iPad，然后选到门店支付            亲爱哒，您在下单的时候支付方式选择门店支付，提交订单后24小时内去任意门店支付就可以的哦。门店支付可以使用现金，刷卡，礼品卡付款。温馨提示门店支付，不支持优惠券或者云钻等抵扣哦~
# 8115                                   好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 8221                         退货的云钻什么时候返还啊      订单退货完成后，云钻和未过期的优惠券将会在24小时内返还到账户；免息券不退哦 （温馨提示：已发出的运费券无法退还，并且券过期了也是不会退回的，商家订单取消时需要选择退货退款，否则不予退还哦）
# 15795                              好的，谢谢。                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 22934                               好的谢谢了                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 4961                           退货的时候忘记弄发票                                           您好，给下订单信息，苏苏帮您核实一下，（温馨提示：若您当时开具了纸质发票，退货时需将发票一起寄回，电子发票无需寄回）
# 22406                               好的 谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 14513                       门店付款是不是货到付款呢？            亲爱哒，您在下单的时候支付方式选择门店支付，提交订单后24小时内去任意门店支付就可以的哦。门店支付可以使用现金，刷卡，礼品卡付款。温馨提示门店支付，不支持优惠券或者云钻等抵扣哦~
# 2781                               好的，谢了！                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 1860                                   好吧                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 21056                                   哦                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 7862                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 17932                              好吧，谢谢你                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 16654              过后发现有问题呢！收货了还可以退回么[微笑]  1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...
# 11202                                申请退款  您可“$url=https://assss.suning.com/assss-web/wap/servicefusion/goReturnChangeList_0.do&name=点击这里$进...
# 18323                               还是谢谢您                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23226                                谢谢啦，                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19808                               发什么快递                如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递），厂家配送和商家商品用的是第三方快递，如：韵达、圆通、申通、中通、顺丰、EMS等
# 249                                    谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23437                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12651                              好的，麻烦了                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 8950                              也没看到发票啊  可以先进入订单中心，查看自己的发票类型， 普通发票一般是放于购物袋/纸箱内或者粘在包装上，还请您仔细找下，厂送发票需要点击确认收货后5-7工作日寄送，增值税发票是需要完成认证后5-7工作日寄送...
# 18953                           打送货的电话没人接                                            您好，快递员联系不上可能是正在配送途中，建议您稍后联系，若多次联系不上，可以点击【联系客服】，由客服MM为您催促。
# 4093                                    哦                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19459                                 谢谢了                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 14323                                  好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 8495                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 3884                              领劵再减220                  您好，所有的优惠活动可以关注易购主页或商品购买页的【促销活动】栏，会有领券、满减、赠品等活动，具体活动以页面为准，优惠后的价格以支付时为准，无法手动给您直接调价的哈。
# 16483                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 15759                               好的，谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19884                               不用了谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 18359                               好吧，谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 18663                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12587                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 8325                                   好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 22725                            什么是苏宁支付？  苏宁支付方式目前有任性付、门店支付、易付宝支付、网银支付、快捷支付、分期付款、支付宝支付、微信支付、企业汇款、货到付款、和扫码支付，找人代付。您可以点击链接http://help.suning...
# 4706                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 10381                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 135                                 好的 谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 17085                                   嗯                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 747                               好的，谢谢您！                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 21473                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 21029                                谢谢亲了                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19477                    你好 注册过的苹果手机可以退货吗  1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...
# 22798                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 15765                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 1069                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 1866                                 好的谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 7808                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 15550                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 22939                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 805                                    谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 5142                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 11097                     门店价格跟你们这一样不[冒汗]                       您好，苏宁门店和易购同一型号商品基础价格是一致的，但是部分活动商品及特价促销商品会存在价格差异，具体可以预约门店导购咨询哦，APP端点击首页身边的苏宁即可。
# 3005                                  谢谢您                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12482                                  好吧                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 16451                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 9430                           还有怎么退费如果拒收      您好，由苏宁快递配送的商品您在拒收以后自动为您办理退款（如已到了末站配送状态可和物流记录上的师傅拒收下呢）。退单后退款回您的原支付账户。第三方快递配送的商品请及时与页面客服客服联系办理退款。
# 5039                                 嗯麻烦了                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 11472                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 18425                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12822                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 16070                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12752                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 20248                                 谢谢你                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 11764                                  好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 3512                         请问你们的发货点是哪儿。                                               【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 13258                              好的，谢谢啊                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 6743                                好的，谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 14800                               好的，谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 11893                                好的谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23326                               没法实名？  您可[link url=https://ema.suning.com/epps-miaw/index.htm]点击这里[/link]进行实名认证操作,目前实名认证支持绑定银行卡认证，仅限大陆二...
# 2825                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 10152                               好的，谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12808                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 3465                           我这个是自营仓发货吗                                               【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。非苏宁发货商品在购买页或物流信息查询里会显示发货地。
# 5607                                   哦哦                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19029                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 5639                                嗯好的谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 8282                                好的，谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19946                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 6446                                    嗯                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 7866                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 7144                               好的，谢谢！                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 22808                                你说降没  您在苏宁易购购买自营商品收货前及收货次日起七天内，如果发现同一城市同一销售渠道的商品售价低于您购买时的价格，您可提交七天贵就赔申请，苏宁将依据本政策将差价以自营无敌券的形式返还给您。电脑端：点...
# 6169                                 谢谢您了                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 16980                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 12144                            安装费是多少呢亲  苏宁安装新机安装免人工费，工程师服务前向用户出示收费价目表/明细，并提前做好预算取得顾客同意，收费不得高于页面标准http://help.suning.com/page/id-478.htm，...
# 22926                         我现在才看到有以旧换新  以旧换新流程(选择机型→描述商品状态→查看估价→选择上门交易方式→获得回收款），电脑端：http://hx.suning.com/video_index.htm 具体您可以在这个页面操作哦。手...
# 15060                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 13966                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 21791                                  谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 20125                                  好的                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 7201                                   谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 13538                        退款的钱可以退到别的号吗                                             申请退货成功后，苏宁易购将按原支付方式原路退回；（温馨提醒：门店支付前往门店退款，货到付款根据自己提交选择退款）
# 16569  我买的油烟机3899，现在才3799，保价赔的为什么是优惠卷，我不要  贵就赔是指您在海外购购买自营商品收货前或收货次日起七天内，如果发现商品页面售价低于您购买时的价格，您可提交贵就赔申请，海外购将依据本政策将差价以自营无敌券的形式返还给您。(仅在收货前支持补差)...
#
#                                                                                                       坐席回复     score
# 2872                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 1115                                               手机端：点击链接选择手机以及配件https://c.m.suning.com/03homePage.html。  0.993216
# 18809                                                                                             不客气，应该的哈  0.833652
# 13791                                                        如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递）  0.887623
# 18272                                                              您在下单的时候支付方式选择门店支付，提交订单后24小时内去任意门店支付就可以的  0.897500
# 8115                                                                         不客气，亲爱哒，很高兴为您服务。还有什么可以帮您？[握手]  0.892550
# 8221                                                                     订单退货完成后，云钻和未过期的优惠券将会在24小时内返还到账户；）  0.805869
# 15795                                                                                      不客气，亲爱哒，很高兴为您服务  0.981664
# 22934                                                                         不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持。  0.993809
# 4961                                                                   亲亲若您当时开具了纸质发票，退货时需将发票一起寄回，电子发票无需寄回的  0.854291
# 22406                                                                                      不客气，亲爱哒，很高兴为您服务  0.981664
# 14513                                        您在下单的时候支付方式选择门店支付，提交订单后24小时内去任意门店支付就可以的哦。门店支付可以使用现金，刷卡，礼品卡付款。  0.972386
# 2781                                                                                       不客气，亲爱哒，很高兴为您服务  0.981664
# 1860                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 21056                                                                             亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持~  0.993155
# 7862                                                                                          不客气，很高兴为您服务。  0.976779
# 17932                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 16654                                                       自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货。  0.814946
# 11202  您可“$url=https://assss.suning.com/assss-web/wap/servicefusion/goReturnChangeList_0.do&name=点击这里$进...  0.923148
# 18323                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 23226                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 19808                                                        如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递）  0.887623
# 249                                                                                       不客气，亲爱哒，很高兴为您服务。  0.981664
# 23437                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 12651                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 8950                                                                                厂送发票需要点击确认收货后5-7工作日寄送，  0.838508
# 18953                                                                            您好，快递员联系不上可能是正在配送途中，稍后再联系  0.860910
# 4093                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 19459                                                                                 [鲜花]不客气，亲爱哒，很高兴为您服务。  0.882761
# 14323                                                                                  很高兴为您服务。感谢您对苏宁易购的支持  0.991844
# 8495                                                                           不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 3884                                                             您好， 商品价格会随着促销信息与活动有一定变动的。具体的是以当时支付的价格为准的。  0.839685
# 16483                                                                                      不客气，感谢您对苏宁易购的支持  0.978416
# 15759                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 19884                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 18359                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 18663                                                                               不客气 亲爱哒 很高兴为您服务 祝您生活愉快  0.921242
# 12587                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 8325                                                                           不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支出  0.993496
# 22725                                                                             苏宁支付方式目前有任性付、易付宝支付、网银支付等  0.879004
# 4706                                                                                       不客气，亲爱哒，很高兴为您服务  0.981664
# 10381                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 135                                                                           不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，  0.993809
# 17085                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 747                                                                                        不客气，亲爱哒，很高兴为您服务  0.981664
# 21473                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 21029                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 19477  1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...  0.898494
# 22798                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 15765                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 1069                                                                           不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 1866                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 7808                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 15550                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 22939                                                                                      不客气，亲爱哒，很高兴为您服务  0.981664
# 805                                                                                                不客气，亲爱哒  0.894234
# 5142                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 11097                                                                       您好，苏宁门店和易购部分活动商品及特价促销商品会存在价格差异  0.851109
# 3005                                                                                        不客气，亲.很高兴为您服务。  0.969164
# 12482                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 16451                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 9430                                                             亲，由苏宁快递配送的商品您在拒收以后自动为您办理退款。退单后退款回您的原支付账户。  0.864797
# 5039                                                                                       不客气，亲爱哒，很高兴为您服务  0.981664
# 11472                                                                                        不客气，亲爱哒，应该做的哈  0.846766
# 18425                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 12822                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 16070                                                                                              不客气，亲爱哒  0.894234
# 12752                                                                                      不客气，亲爱哒，很高兴为您服务  0.981664
# 20248                                                                                      不客气，亲爱哒，很高兴为您服务  0.981664
# 11764                                                                                      不客气，亲爱哒，很高兴为您服务  0.981664
# 3512                                                                          【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。  0.922657
# 13258                                                                                             不客气，亲爱哒，  0.894234
# 6743                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 14800                                                                             不客气，亲爱哒，很高兴为您服务还有什么可以帮您？  0.928328
# 11893                                                                         不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持。  0.993809
# 23326                                                您可https://ema.suning.com/epps-miaw/index.htm 进行实名认证操作  0.832504
# 2825                                                                                              不客气，亲爱哒，  0.894234
# 10152                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 12808                                                                         不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，  0.993809
# 3465                                                                          【苏宁发货】商品会根据您收货地址自动选择就近的仓库发货。  0.922657
# 5607                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 19029                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 5639                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 8282                                                                                               不客气，亲爱哒  0.894234
# 19946                                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持  0.993809
# 6446                                                                                   很高兴为您服务。感谢您对苏宁易购的支持  0.991844
# 7866                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 7144                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 22808          您在苏宁易购购买自营商品收货前及收货次日起七天内，如果发现同一城市同一销售渠道的商品售价低于您购买时的价格，您可提交七天贵就赔申请，苏宁将依据本政策将差价以自营无敌券的形式返还给您。  0.831479
# 6169                                                                                      不客气，亲爱哒，很高兴为您服务。  0.981664
# 16980                                                                                                  不客气  0.852193
# 12144                          苏宁安装新机安装免人工费，工程师服务前向用户出示收费价目表/明细，收费标准http://help.suning.com/page/id-478.htm  0.926793
# 22926                       以旧换新流程(选择机型→描述商品状态→查看估价→选择上门交易方式→获得回收款）如果操作最后显示此地区暂时还不支持回收，就回收不了，后面会在继续扩大回收范围。  0.806530
# 15060                                                                         不客气，亲爱哒，感谢您对苏宁的支持，祝您生活愉快，再见！  0.919541
# 13966                                                                         不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，  0.993809
# 21791                                                                                 不客气，亲爱哒，很高兴为您服务。您稍等哦  0.965776
# 20125                                                                                     不客气，亲爱哒，很高兴为您服务。  0.981664
# 7201                                                                                 不客气，亲爱哒，很高兴为您服务。您先稍等哦  0.954812
# 13538                                                                              申请退货成功后，苏宁易购将按原支付方式原路退回  0.844590
# 16569                贵就赔是指您在海外购购买自营商品收货前或收货次日起七天内，如果发现商品页面售价低于您购买时的价格，您可提交贵就赔申请，海外购将依据本政策将差价以自营无敌券的形式返还给您。  0.909744

# %%
ha_answer_99.loc[[1,152,177,23709,23770,3,21],['用户问题', '参考答案', '坐席回复', 'score']]
# Out:
#                   用户问题                                                                                                 参考答案                                              坐席回复     score
# 1           那要是裸机是不是不保                                                     裸机是指没有绑定任何合约购买的手机，不是只有手机的哈，自带充电器也是有的，具体以包装清单为准的哦  俯首是春，仰首是秋，每一次的期待都盼望与您相遇！感谢您的咨询，还有什么需要小苏帮助您的呢[鲜花]  0.240055
# 152            易付宝怎么激活          电脑端自助修改：登录账户（非信任登录），点击立即使用认证，如果该实名认证信息非本人，点击页面“申请变更”，根据页面提示上传资料（身份证正反面，手持身份证照片），等待1个工作日内审核。                                        您需要下载苏宁金融亲  0.114642
# 177       安装费还有架子怎么收费的  您好，新机安装过程中，包装箱以外增加的材料、配件等是另计收费的！安装前工人会先为您做价格预算，收费时会出示价目表，请您放心！具体安装价格公示优先查看该商品的详情页，另外对于路程较远的地址可能会...                      亲，麻烦提供一下您的订单号或者手机号我们这边帮您查询一下  0.300803
# 23709            包安装吗？  大家电提供安装服务，可在商品购买页查看安装服务方，如显示苏宁安装，配送完成后，会有当地网点跟您预约安装时间；如果显示供应商提供安装服务，需自行联系厂家进行预约安装，（商品页面--售后保障-售后...                                         是我们苏宁安装的呢  0.433300
# 23770     安装是需要购买什么东西吗  您好，苏宁安装新机大部分品类安装免人工费，工程师服务前向用户出示收费价目表/明细，若涉及原配件之外的材料是按照收费标准，具体可参考商品详情页安装收费标准或$url=http://help.su...                                        三角阀、软管、接头等  0.024332
# 3                 有质保吗                          您好，  因商品生产批次较多，因商品生产批次较多，暂无法确定您购买商品的生产日期，不过请您放心，苏宁所卖商品均按照国家要求的保质期管理规范进行操作的。                                              亲 有的 -0.023777
# 21     我在苏宁总部，明天可以送到吗？  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。http://order.suning....                                              可以的亲 -0.018216

# %%
display(ha_answer_99[ha_answer_99['score']<0.8][['用户问题', '参考答案', '坐席回复', 'score']])
# Out:
#                                                                                                       用户问题  \
# 0                                                                                             物流太差了，跟京东没得比
# 1                                                                                               那要是裸机是不是不保
# 3                                                                                                     有质保吗
# 4                                                                                       货到付款的订单能不能修改成在线支付？
# 9                                                                                                大晚上联系我干啥？
# 16                                                                                                   好了，谢谢
# 18                                                                                                      好吧
# 19                                                                                               那什么时候能有货呢
# 20                                                                                                  我还是抢不到
# 21                                                                                         我在苏宁总部，明天可以送到吗？
# 26                                                                                                      谢谢
# 31                                                                                        为什么我没有看到有免运费的选项啊
# 32     以旧换新流程(选择机型→描述商品状态→查看估价→选择上门交易方式→获得回收款），电脑端：http://hx.suning.com/video_index.htm 具体您可以在这个页面操作哦。手...
# 33                                                                                        你们是不是还支持7天无理由退货？
# 40                                                                                        我买了2副Beats的蓝牙耳机了
# 46                                                                                                  买别的就可以
# 48                                                                                               还是不行，不能结算
# 52                                                                                  也可以去店里去自取吗？这样的话可以当场验货啊
# 54                                                                                             大王 卡是免费赠送的吗
# 64                                                                                               不能用发什么优惠卷
# 68                                                                                                   嗯，谢谢！
# 73                                                                                            你们这个真的让人好无语啊
# 76                                                                                                就是下载不了软件
# 77                                                                                                   怎么更改？
# 78                                                                                               请告诉我怎么处理，
# 95                                                                                             投诉到你们明天就过期了
# 98                                                                                     我想咨询一下我为什么买空调没有领到云钻
# 102                                                                                                 等了一了一天
# 105                                                                                                   噢噢好的
# 107                                                                                             如果降价可以退差价吗
# 112                                                                                                     是的
# 118                                                                                                   还是不行
# 124                                                                         我的意思是 已经申请成功 在7天之内 发现又降价了 怎么办？
# 127                                                                                                  怎么操作呢
# 131                                                                                           核桃奶生产日期是几月的？
# 133                                                                                      在线下单可以去附近的苏宁门店自提吗
# 138                                                                                                    买不了
# 142                                                                                                说是11号送的
# 148                                                                                                      嗯
# 149                                                                                                好的，多谢了！
# 150                                                                                               这个能门店自提吗
# 152                                                                                                易付宝怎么激活
# 155                                                                                                      ？
# 160                                                                                                  电话号码？
# 164                                                                                                  这是啥意思
# 169                                                                                              为什么还是买不了呀
# 171                                                                                                  没人来安装
# 176                                                                                             这个没有收费标准吗？
# 177                                                                                           安装费还有架子怎么收费的
# 181                                                                                                不想消费者利益
# ...                                                                                                    ...
# 23603                                                                                         绑定的你们苏宁微信公众号
# 23619                                                                              我也是按着这个订单重新购买的为什么就没有赠品？
# 23624                                                                                             等于是退款对吗？
# 23627                                                                                      这款滤芯24小时用，可以用多久
# 23634                                                                                             明天保证送达是吧
# 23641                                                                                                 谢谢??
# 23646                                                                                            亲 拼团是什么意思
# 23652                                                                                          我看出产日期是15年的
# 23659                                                                                          换屏是在一年保修里面吗
# 23670                                                                                                   好的
# 23674                                                                                                   好的
# 23677                                                                                             我到页面咨询一下
# 23678                                                                                            电子发票开不了啦？
# 23680                                                                                            连个预约电话都没有
# 23682                                                                        我已经办理退货的苹果笔记本电脑，想要确认一下是不是可以退货
# 23686                                                                                 怎么联系你们，我怕现场无法和你们及时沟通
# 23695                                                                                           你们服务比京东差远了
# 23709                                                                                                包安装吗？
# 23713                                         http://product.suning.com/0000000000/000000000191422311.html
# 23717                                                                                            感觉空调效果不好，
# 23724                                                                                        我这个钱能退到别的银行卡吗
# 23730                                                                                           别的型号的不可以了啊
# 23731                                                                                                    好
# 23733                                                                                                多久会退款
# 23739                                                                                              手机咋买不了啊
# 23741                                                                                        亲今天能知道我手机修好了吗
# 23745                                                                                                   好的
# 23747                                                                                           那你能帮我反馈一下吗
# 23757                                                                                              自营是什么意思
# 23762                                                                                                   是的
# 23763                                  ￥380 [全额抵用] ￥52.6[全额抵用] 我账户里有两张抵用券 问1 这是不是贵就赔自动补偿的？ 问2 张对应的是哪两个订单号？
# 23770                                                                                         安装是需要购买什么东西吗
# 23776                                                                                                  没有了
# 23781                                                                                           金质习酒啥时候有货？
# 23784                                                                                           我这个退款可以了么？
# 23794                                                                                         一单两个产品，只收到一个
# 23801                                                                      哦哦，超过7天了，有质量问题也没法退了哈，超15天连换都不行哈
# 23802                                                                                                嗯嗯 好的
# 23809                                                                                     如果有质量问题你们承担寄回运费吗
# 23811                                                                                       购机型号与收货型号有点不一致
# 23814                                                                                    6月24日收到的退货 什么时候退款
# 23821                                                                                                   是的
# 23823                                                                                                   等等
# 23826                                                                                                   谢谢
# 23829                                                                                                   是的
# 23834                                                 我使用微信支付的，至今未收到退款，绑定的银行卡我也查了这个月的记录，也没有收到退款，请问退款完成怎么说。
# 23836                                                                                        退款什么时间能到我的账上？
# 23837                                                                                              好的，谢谢了。
# 23839                                                                                           可以当电脑显示器用？
# 23845                                                                                             自提和配送的区别
#
#                                                                                                       参考答案  \
# 0                                                                           非常抱歉给您添麻烦了。亲和苏苏说一下情况，苏苏这边帮您处理。
# 1                                                         裸机是指没有绑定任何合约购买的手机，不是只有手机的哈，自带充电器也是有的，具体以包装清单为准的哦
# 3                              您好，  因商品生产批次较多，因商品生产批次较多，暂无法确定您购买商品的生产日期，不过请您放心，苏宁所卖商品均按照国家要求的保质期管理规范进行操作的。
# 4      下单的时候保存详细的收货地址，在支付方式里面会显示是否支持货到付款的，如果不支持的话会提示您使用在线支付。选择货到付款的支付方式，您可以选择现金支付或者移动POS刷卡支付。点击链接http:/...
# 9                                                                                    很抱歉，让您久等了。请选择以下售后问题咨询
# 16                                                                                           不客气，亲爱的，应该的哈！
# 18                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 19                                                                      您这边在下单的时候选择您的城市地址，能够成功下单支付的都是有现货的哦
# 20                                                网站不提供价格、库存保护，因工厂调价、促销结束、抢购等造成的价格、库存变化以付款时为准。给您造成不便，敬请谅解！
# 21     【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。http://order.suning....
# 26                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 31     1.自实际收货日期的次日起7天内退货（部分已激活商品不支持无理由退），有质量问题15天内可换货，https://assss.suning.com/assss-web/wap/servicefu...
# 32                                    上门回收后，24小时内易付宝线上给您打款。邮寄回收的前往我的易购-我的服务-以旧换新-我的-我的订单查看进度。邮寄需要时间请耐心等等哦。
# 33     页面标注的符合7天无理由退货，商品完好的情况下可办理，具体可点击$url=https://assss.suning.com/assss-web/wap/servicefusion/goRetu...
# 40     煲耳机刚开始用轻柔一些的音乐，在较低音量下让耳机先舒缓10-30小时，然后用普通的音乐(摇滚、舞曲除外)在中等音量状态煲100-200小时。这时你听着高音不刺耳了，变得圆润自然，中音温暖亲切，...
# 46     待支付的订单若需要修改支付方式，电脑端点击https://order.suning.com/order/orderList.do?transStatus=waitPay 手机端点击我的易购-待...
# 48                                                           因产品服务升级，当前该业务暂停服务，开启时间待定，建议多多关注页面。给您带来不便，敬请谅解
# 52     下单时在配送方式里选择自提，可选择门店自提或者自提柜自提，自提时间可参考下单时选择的指定配送时间（我的订单-物流查询），下单后需收到短信验证码再去对应自提点提货，商品在自提柜可保留3天，自提点...
# 54                清洗服务需要费用的哦，实际收费标准需清洁师上门判断清洗类型确定后为准的，可以参考http://help.suning.com/page/id-535.htm，请问您需要预约吗？
# 64     您可以在订单结算页面点击“使用优惠券”勾选可使用的券（如果无法勾选，证明这个券不适用此活动），在不可用券一栏可以查询具体不可使用原因。各类券的使用规则您可以$url=http://help.s...
# 68                                                          不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 73                                                                     抱歉给您带来困扰了，麻烦具体情况可以先和小妹描述下，方便为您核实处理呢
# 76     商品详情中会有系统的相关介绍，海信、创维、康佳、长虹、TCL是安卓定制系统兼容安卓的，三星、LG、创维是厂家研发的系统；智能电视有操作系统，只能在应用平台中下载软件！先锋智能电视也是不支持下载...
# 77     发票内容为您所购买的商品明细，发票金额为所购商品实际支付金额（不含礼品卡、优惠券、云钻等支付部分），并且无法进行修改。如果您需要更改发票抬头或税号，若刚下单或未发货建议取消订单重新下单，取消之...
# 78                                                                              非常抱歉给您添麻烦了。MM马上帮您核实处理请稍等哦！
# 95                                                         确实很抱歉给您带来不便，为了更好更快速地解决您的问题，点击转人工联系客服MM为您处理#转人工#
# 98                              评价获得云钻会在是评价后24小时内到账，购物云钻需要订单支付完成24小时内将相应云钻返至您的账户，选择货到付款会有一定时间延迟，建议您选择在线支付。
# 102                                                                                  很抱歉，让您久等了。请选择以下售后问题咨询
# 105                                                                                         好的，还有什么可以帮您的吗？
# 107    http://assss.suning.com/assss-web/wap/sNWapPriceProtectedController/getWapPriceProtectedList_1_0...
# 112                                                                                                    好嘞！
# 118                                                 抱歉哦亲亲，给您带来不便，请您提供下两次以上维修凭证和第三次无法维修同一故障的故障证明单据哦我为您反馈申请。
# 124    您在苏宁易购购买自营商品收货前及收货次日起七天内，如果发现同一城市同一销售渠道的商品售价低于您购买时的价格，您可提交七天贵就赔申请，苏宁将依据本政策将差价以自营无敌券的形式返还给您。点击链接h...
# 127    您好，分期付款您可以在下单结算界面选择“信用卡分期”，支付成功后，银行会一次性扣除总金额，后期每个月给银行还款分期的金额；或者您选择任性付分期，3/6/9/12期都是可以的哦（部分商品会有免息...
# 131         由于进货批次不同生产地点不同，生产日期具体可以在包装上查询，不过您放心我司所售产品均在保质期内，部分临期的商品会在页面做临期提示，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 133    下单时在配送方式里选择自提，可选择门店自提或者自提柜自提，自提时间可参考下单时选择的指定配送时间（我的订单-物流查询），下单后需收到短信验证码再去对应自提点提货，商品在自提柜可保留3天，自提点...
# 138            1.是否是参加活动，活动商品已经结束导致支付不了；2.超了支付时间或商品无货会导致订单无法支付，建议重新下单或购买其他商品；3.同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 142    【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 148                                                         不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 149                                                                                         好的，还有什么可以帮您的吗？
# 150                                    您好，我司自营中小件是支持自提的，您下单选择门店自提-商品配送至门店后-短信通知您提货。收到短信通知后自提柜可保留3天，自提点7天的哈
# 152            电脑端自助修改：登录账户（非信任登录），点击立即使用认证，如果该实名认证信息非本人，点击页面“申请变更”，根据页面提示上传资料（身份证正反面，手持身份证照片），等待1个工作日内审核。
# 155                                                                                   请问您具体想问什么问题呢？能否具体说一下
# 160                                                                 亲，苏宁热线是4008-365-365，您有什么问题这边也是可以帮您处理的呢
# 164            1.是否是参加活动，活动商品已经结束导致支付不了；2.超了支付时间或商品无货会导致订单无法支付，建议重新下单或购买其他商品；3.同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 169            1.是否是参加活动，活动商品已经结束导致支付不了；2.超了支付时间或商品无货会导致订单无法支付，建议重新下单或购买其他商品；3.同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下
# 171                                                                    抱歉给您带来困扰了，麻烦具体情况可以先和小妹描述下，方便为您核实处理呢
# 176    您好，苏宁安装新机大部分品类安装免人工费，工程师服务前向用户出示收费价目表/明细，若涉及原配件之外的材料是按照收费标准，具体可参考商品详情页安装收费标准或$url=http://help.su...
# 177    您好，新机安装过程中，包装箱以外增加的材料、配件等是另计收费的！安装前工人会先为您做价格预算，收费时会出示价目表，请您放心！具体安装价格公示优先查看该商品的详情页，另外对于路程较远的地址可能会...
# 181                                                        确实很抱歉给您带来不便，为了更好更快速地解决您的问题，点击转人工联系客服MM为您处理#转人工#
# ...                                                                                                    ...
# 23603                                                                您可以点击我的易购-设置-安全设置-关联账号进行绑定或者解绑微信、QQ账号
# 23619  有无赠品以及赠品详情以下单时网页描述为准，部分赠品随主商品一同生成订单了则是随主商品一起寄送，部分赠品是“好评晒单”后单独寄出，详细规则以购买商品页面活动介绍为准（需收货45天内好评晒单，超时...
# 23624  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 23627  不同的滤芯更换周期是不同的，具体以产品售后这边回复为准哈。以下数据您可以参考下哈，这个数据根据顾客家中水质和使用情况，是有所增减的喔： Pp棉滤芯：3-6个月 活性炭滤芯：8-12个月 超滤膜...
# 23634  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。电脑端http://order.suni...
# 23641                                                                                        不客气，亲爱的，应该的哈！
# 23646  选择乐拼购商品开团或者参团-付款成功-微信分享好友达到拼团人数-24小时达到拼团要求，拼团成功。手机端：https://c.m.suning.com/group_index.html?adTy...
# 23652       由于进货批次不同生产地点不同，生产日期具体可以在包装上查询，不过您放心我司所售产品均在保质期内，部分临期的商品会在页面做临期提示，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！
# 23659                                                    您可以在商品页面点击【售后保障】看到该商品的具体售后服务和保修期（具体保修时间以产品保修卡为准）。
# 23670                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23674                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23677                                                                                亲，提供一下订单信息，苏苏这边帮您核实一下
# 23678  电子发票会在确认收货后48小时内开具，可以$url=http://res.m.suning.com/project/orderOther/dist/myInvoice.html#/&name=...
# 23680                                                                                 这边可以为您预约安装的哦，亲给下订单信息
# 23682  商品出现非人为质量问题以及支持无理由退换货的商品可自助申请退换货，自实际收货日期的次日起7天内退货，有质量问题15天内可换货，可[link url=http://assss.suning.co...
# 23686                                                               亲，苏宁热线是4008-365-365，您有什么问题这边也是可以帮您处理的呢
# 23695                                                        很抱歉给您带来困扰了 ，请问具体情况可以简单描述下.这可帮您联系下师傅和大区售后这边处理呢
# 23709  大家电提供安装服务，可在商品购买页查看安装服务方，如显示苏宁安装，配送完成后，会有当地网点跟您预约安装时间；如果显示供应商提供安装服务，需自行联系厂家进行预约安装，（商品页面--售后保障-售后...
# 23713                                                                                您好，请问关于这款商品，有什么可以帮到您？
# 23717  变频空调的压缩机能够在长期开启运转的情况下适度调温，如果室内不需要大量冷热时，空调就会以低频的状态运转，智能的恒定控温，而定频产品则需要在人为的情况下进行空调冷热的开关机调节。简单的说如果长时...
# 23724                                                               拼团有效期24小时内未邀请到足够人数参团即拼团失败，已付款原路退还支付账户。
# 23730  实际收货日期的次日起7天内可以申请退货（部分已激活商品不支持无理由退，无理由退货需保证商品附件包装完好不影响二次销售），有质量问题15天内可换货，[link url=http://assss....
# 23731                                                                               感谢您对苏宁易购的支持，祝您生活愉快再见~-
# 23733  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 23739  目前任性付购物贷款支持在苏宁门店以及苏宁易购使用。苏宁门店通过苏宁金融APP扫码支付，无需再次审核；苏宁易购需提交订单后选择任性付支付，其中虚拟商品、黄金、金银投资之外的所有商品（汽车除外），...
# 23741  【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。非苏宁发货商品下单后在48小时内发货，以快递信息为准。https://res.m.suning...
# 23745                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23747                                                                           很抱歉没有帮到您,您可以点此转人工为您服务#转人工#
# 23757                                         商品页面输入您的省市区显示：由“苏宁”销售的就是苏宁自营，商品标题左上角也会有自营两个字，说明此款商品使我们苏宁自营的。
# 23762                                                                                                  好嘞！
# 23763                                   您好，在订单结算页面点击“使用优惠券”勾选可使用的券（如果无法勾选，证明这个券不适用此活动哦），具体原因可点击该券查看具体使用规则。
# 23770  您好，苏宁安装新机大部分品类安装免人工费，工程师服务前向用户出示收费价目表/明细，若涉及原配件之外的材料是按照收费标准，具体可参考商品详情页安装收费标准或$url=http://help.su...
# 23776                                                              尊敬的客户，感谢您对苏宁金融产品的支持！关于这个问题我这边查看下，马上回复您哦
# 23781                                                您好，请输入您所在的城市（市），部分地区情况有所不同。（如果您不是要查询商品的库存或价格，请回复“不是”）
# 23784  退货完成后退款原路退回，退款最快2小时左右到账，支付宝，微信，易付宝等余额支付的是会在24小时内退款到账的，储蓄卡3-5个工作日内到账，信用卡3-7个工作日内到账，货到付款现金支付的退款到银行...
# 23794                                                       亲亲，如果错漏发、破损漏液了在线这边会为亲您尽快处理的。亲稍等下哦，我这边给您查看下订单先。
# 23801  亲，您购买带有“30天包退，365天包换”标识的商品，若出现质量问题，自收货次日可30天内办理退货，365天内办理换货，电脑端http://assss.suning.com/assss-web...
# 23802                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23809                                                    若是无理由退货需要您自行承担运费哦，质量问题退换货免取件费，商家退换货运费建议咨询购买页面商家客服
# 23811                                   您好，商品信息以页面展示为准哦，颜色规格等可以在页面选择也可进入商品页面点击“包装及参数”查询到该商品的详细功能及参数配件信息等。
# 23814  您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账，您可以 [link url=http://assss.suning.c...
# 23821                                                                                                  好嘞！
# 23823                                                                                             恩，好的，不急。
# 23826                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23829                                                                                                  好嘞！
# 23834  您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账，您可以 [link url=http://assss.suning.c...
# 23836  您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账，您可以 [link url=http://assss.suning.c...
# 23837                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。
# 23839                                                          如果您电脑主机和电视上都有VGA接口，那这电视可以连接电脑主机，作为电脑显示器使用的。
# 23845                自提、配送都是从中心仓发货的，时间上相差不大。在物流信息中会告知预计到货时间，到货之后会第一时间通知您。请以实际收货时间为准。（温馨提示：送货方式在订单提交后不支持修改）
#
#                                                                                                       坐席回复     score
# 0                                                                                         亲 请问还有其他可以为您服务的吗  0.526001
# 1                                                         俯首是春，仰首是秋，每一次的期待都盼望与您相遇！感谢您的咨询，还有什么需要小苏帮助您的呢[鲜花]  0.240055
# 3                                                                                                     亲 有的 -0.023777
# 4                                                          欠款-物流收 李小姐 15915717838 广州市南沙区全区南沙街珠电路中央郡5栋1003房  0.111694
# 9                                                                                                很抱歉，让您久等了  0.630947
# 16                                                                             麻烦您了，不客气，亲爱的，应该的哈！还有什么可以帮您？  0.789829
# 18                                                                                          亲，对给您带来的困扰表示抱歉  0.741523
# 19                                                                                             亲 这个小苏也不知道呢  0.242070
# 20                                                                                                    稍等的哈  0.274749
# 21                                                                                                    可以的亲 -0.018216
# 26                                                                                                 不客气[再见]  0.629474
# 31                                                                                        是的哈亲   上门取件免运费的呢 -0.011416
# 32                                                        俯首是春，仰首是秋，每一次的期待都盼望与您相遇！感谢您的咨询，还有什么需要小苏帮助您的呢[鲜花]  0.409043
# 33                                                                                很高兴为您服务，请问还有其他问题可以帮到您的吗？ -0.075999
# 40                                                                                                     好的呢  0.262839
# 46                                                           因产品服务升级，当前该业务暂停服务，开启时间待定，建议多多关注页面。给您带来不便，敬请谅解  0.006621
# 48                                                                                     在的哦亲   请问有什么可以帮您的哦？  0.326173
# 52     您在下单的时候把配送方式选为自提，会自动显示您当地就近的自提点的（不显示则当地无自提点），货到了自提点会短信告知您自提校验码，您凭校验码提货。（提示：并不是下单立即就能去自提的哟，需收到校验码...  0.799733
# 54                                                                                          亲  有的赠送有的是增值业务 -0.035368
# 64                                                                                         券的使用以下单勾选为准哦，亲，  0.318360
# 68                                                                                                   不客气，亲  0.797121
# 73                                                                                              小苏这边帮您查询一下  0.669005
# 76                                                                                                      稍等 -0.110499
# 77                                                                                            您下单后我们这边帮您修改  0.345378
# 78                                                                                        不好意思啊，该商品没有电子发票呢  0.088889
# 95                                                                                      确实很抱歉给您带来不便，请您稍等一下  0.719270
# 98                                                                                     亲 请稍等2分钟，这边立即帮您核实下哦  0.119511
# 102                                                                              很抱歉，让您久等了,这边正在对接物流负责人加急安排  0.656794
# 105                                                                                                   [微笑]  0.297811
# 107    亲亲，现在不支持补钱哦，只能补券呢！苏宁自营实物商品自收货次日起7日内发生降价，APP用户在-我的易购-我的服务-贵就赔，PC端用户打开网址http://assss.suning.com/as...  0.602229
# 112                                                                                             好嘞！   您稍等~  0.632819
# 118                                                                                   抱歉哦亲亲，给您带来不便，我在帮您查询下  0.624459
# 124                                                                                   7天之内  只要 符合条件就可以进行补差  0.488880
# 127                                                                                                   [太阳] -0.299833
# 131                                                                          请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收！  0.744971
# 133    亲爱的，自营小件商品支持自提，您在下单的时候把配送方式选为自提，会自动显示您当地就近的自提点的（不显示则当地无自提点），货到了自提点会短信告知您自提校验码，您凭校验码提货。（提示：并不是下单立...  0.796804
# 138                                                                            同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下  0.750902
# 142                                                      【苏宁发货】商品，页面会显示预计到达时间（以提交订单时显示的时间为准）下单后按照您指定的日期配送。  0.778737
# 148                                                                                                    嗯呢亲  0.184977
# 149                                                                亲 如果对小妹服务满意的话，记得给小妹一个五星好评哦 谢谢您了，在右下角+里。  0.630510
# 150    自营小件商品支持自提，您在下单的时候把配送方式选为自提，会自动显示您当地就近的自提点的（不显示则当地无自提点），货到了自提点会短信告知您自提校验码，您凭校验码提货。（提示：并不是下单立即就能去...  0.784862
# 152                                                                                             您需要下载苏宁金融亲  0.114642
# 155                                                                                   亲，这个问题安装师傅上门后会帮您处理好的  0.502392
# 160                                                                                             亲亲 您有什么问题呢  0.773897
# 164                                                                           .同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下  0.750902
# 169                                                                           .同时支付客户较多，支付拥挤，建议您可以稍后刷新再试一下  0.750902
# 171                                                                                              抱歉给您带来困扰了  0.762205
# 176                                                                           安装费与人工费是免费的，如果用到额外材料需要收取材料费的  0.369931
# 177                                                                           亲，麻烦提供一下您的订单号或者手机号我们这边帮您查询一下  0.300803
# 181                                                                                           确实很抱歉给您带来不便，  0.719683
# ...                                                                                                    ...       ...
# 23603                                                                                              是有什么问题吗 -0.116708
# 23619                                                                                               赠完为止的呢 -0.017347
# 23624                                                                               亲   请问还有其他什么可以帮您的吗？^_^ -0.103526
# 23627                                                                                    亲，按您的这种情况，一般一年左右呢  0.434008
# 23634                                                                                            预计是在明天送达的  0.184801
# 23641                                                                                    不客气，亲爱的，这是小妹应该做的呢  0.799203
# 23646                                                     选择乐拼购商品开团或者参团-付款成功-微信分享好友达到拼团人数-24小时达到拼团要求，拼团成功。  0.779178
# 23652                                                                   由于进货批次不同生产地点不同，不过您放心，我司所售产品均有售后保证的  0.719756
# 23659                                                                                   这边看了您的订单是没有购买碎屏险的呢  0.175803
# 23670                                                                                                不客气，亲  0.797121
# 23674                                                                                                 [飞吻]  0.295190
# 23677                                                                                                 是的，亲  0.225968
# 23678                                                                                         是的，电子发票生成比较慢  0.597453
# 23680                                                                                    亲不好意思给您带了不便，请你稍等。  0.475670
# 23682                                                                                          稍等，小妹查询 ^_^ -0.091690
# 23686                                                                                  亲，苏宁热线是4008-365-365  0.775972
# 23695                                                                                       很抱歉给您带来困扰了[太阳]  0.519558
# 23709                                                                                            是我们苏宁安装的呢  0.433300
# 23713                      您好，由于进货批次不同，生产地点不同，所以日期我们查不到呢，不过您放心，我司所售产品均在保质期内，请您放心购买哦！收货时如果您对保质期不满意，可以选择拒收哦！  0.393289
# 23717                                                                您开空调设置温度 窗户之类的是需要关上后 一段时间后 温度才会慢慢降低的呢  0.547210
# 23724                                                                                             别的银行卡吗亲？  0.458377
# 23730                                                                                    换的话只能换同款的亲，换一模一样的 -0.100594
# 23731                                                                                                    恩 -0.002815
# 23733                                                                                             亲稍等帮您看一下 -0.014817
# 23739                                                                                               亲 系统火爆 -0.018666
# 23741                                                   亲，所谓“术业有专攻”，为了更好的给您解决问题，小妹帮您【对接】我们的专业客服给您处理，您看可以么？ -0.063997
# 23745                                                                                                亲亲稍等哦  0.128604
# 23747                                                                                      可以的亲   很抱歉没有帮到您  0.732612
# 23757                                          亲爱哒，您在苏宁易购购买的产品，原装出厂，保证正品行货，开具全国统一机打发票，享受国家三包规定，全国联保，请放心购买哦  0.350067
# 23762                                                                                            好嘞！马上帮您申请  0.544605
# 23763                                                                                               请您稍等一下  0.002963
# 23770                                                                                           三角阀、软管、接头等  0.024332
# 23776                                                     好的，亲亲，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。  0.799804
# 23781                                                                          您好，请输入您所在的城市（市），部分地区情况有所不同。  0.798368
# 23784                                                                                        亲亲 麻烦提供一下订单号哦 -0.025335
# 23794                                                                                              好的亲请稍等哦  0.630048
# 23801                                                         亲，如果您购买带有“30天包退，365天包换”标识的商品，若出现质量问题，是可以退换的呢  0.678219
# 23802                                                                                             那可能是有影响的 -0.220436
# 23809                                                                                             质量问题免取件费  0.604686
# 23811                                                                                        亲上面收货人的信息是您的么  0.251418
# 23814                                        您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账。  0.765670
# 23821                                                                                      好的亲，那您现在的需求是什么呢  0.510274
# 23823                                                                                            恩，好的，不急。亲 -0.254878
# 23826                                                                                         稍等一下，小妹为您查询。  0.462369
# 23829                                                                                                   好的  0.552927
# 23834                                                                             您好，退货完成后根据支付方式不同退款时间稍有不同  0.556550
# 23836                                         您好，退货完成后根据支付方式不同退款时间稍有不同，一般易付宝支付3个工作日内到账；银联或信用卡支付一般3-7个工作日到账  0.765670
# 23837                                                                                                 不客气呢  0.738680
# 23839                                                                                 亲   活动商品 数量有限 喜欢抓紧哦亲  0.212594
# 23845                                                         自提、配送都是从中心仓发货的，时间上相差不大。自提是发到门店您去提货  配送是送货上门的  0.646074
#
# [5339 rows x 4 columns]

# %% [markdown]
# 问题基本上同tf-idf, 但效果比tf-idf更好
# 在这个数据下, word embedding avg 效果感觉还不错. 能够正确分辨两个句子的主题是否相近, 但现在的数据库相对而言是很干净的, 并没有太多人工输入, 不需要担心同义词和其他可能问题. 另外, 仍然是靠关键字抓主题, 对于细微的语意无法准确分辨
# 对的句子能够拿到高分, 但细微错误的句子也可以拿到高分, 完全错的则是低分

# %% [markdown]
# ## quick-thought

# %% [markdown]
# 参考答案长度太长, 对于模型的训练更加困难, 应检视现有客服人工答案的长度分布
# 可以使用客服手动回答的聊天本文, 让model学会一般问答的配对

# %%
ha_answer_99.loc[[13791, 8221, 4961, 19808, 22725, 9430, 16980],['用户问题', '参考答案', '坐席回复', 'score']]
# Out:
#                用户问题                                                                                                 参考答案                                           坐席回复     score
# 13791     麻烦，发邮政不行吗                如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递），厂家配送和商家商品用的是第三方快递，如：韵达、圆通、申通、中通、顺丰、EMS等  如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递）  0.887623
# 8221   退货的云钻什么时候返还啊      订单退货完成后，云钻和未过期的优惠券将会在24小时内返还到账户；免息券不退哦 （温馨提示：已发出的运费券无法退还，并且券过期了也是不会退回的，商家订单取消时需要选择退货退款，否则不予退还哦）              订单退货完成后，云钻和未过期的优惠券将会在24小时内返还到账户；）  0.805869
# 4961     退货的时候忘记弄发票                                           您好，给下订单信息，苏苏帮您核实一下，（温馨提示：若您当时开具了纸质发票，退货时需将发票一起寄回，电子发票无需寄回）            亲亲若您当时开具了纸质发票，退货时需将发票一起寄回，电子发票无需寄回的  0.854291
# 19808         发什么快递                如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递），厂家配送和商家商品用的是第三方快递，如：韵达、圆通、申通、中通、顺丰、EMS等  如果商品在页面显示“由苏宁销售和发货的”，是由我司苏宁快递给您配送的（无法指定发其它快递）  0.887623
# 22725      什么是苏宁支付？  苏宁支付方式目前有任性付、门店支付、易付宝支付、网银支付、快捷支付、分期付款、支付宝支付、微信支付、企业汇款、货到付款、和扫码支付，找人代付。您可以点击链接http://help.suning...                       苏宁支付方式目前有任性付、易付宝支付、网银支付等  0.879004
# 9430     还有怎么退费如果拒收      您好，由苏宁快递配送的商品您在拒收以后自动为您办理退款（如已到了末站配送状态可和物流记录上的师傅拒收下呢）。退单后退款回您的原支付账户。第三方快递配送的商品请及时与页面客服客服联系办理退款。      亲，由苏宁快递配送的商品您在拒收以后自动为您办理退款。退单后退款回您的原支付账户。  0.864797
# 16980            谢谢                                                       不客气，亲爱哒，很高兴为您服务。感谢您对苏宁易购的支持，如果您对我的服务满意记得给我个赞哈。                                            不客气  0.852193

# %% [markdown]
# 1. 參考答案特別長, 回覆非常詳細, 包含許多用戶並沒有問的問題, 客服回答通常較精簡
# 2. 參考答案一共1000多句, 手邊並沒有參考答案相似的句型, 無法訓練機器人. 在還沒有數據的情況下, 只能以關鍵字匹配為主
# 3. 希望能夠提供優秀客服的問答紀錄. 並以優秀克服的問答來訓練評分模型

# %%
file = open(os.path.join(data_path, "questoin_test.txt"), "r")

# %%
q_ids = []
qs = []
scores = []
sim_qs = []
stan_qs = []
act_qs = []

# %%
q_id = 0
n = 0
for line in file.readlines():
    if line[0]=='q':
        q_id += 1
        q = line.split("=")[-1].strip()
        continue
    elif line[0]=='S':
        segs = line.strip().split("  ||  ")
        score = round(float(segs[0].split("=")[-1].strip()),2)
        sim_q = segs[1].split("=")[-1].strip()
        stan_q = segs[2].split("=")[-1].strip()
        n += 1
    else:
        act_q = line.split(":")[-1].strip()
        act_qs.extend([act_q]*n)
        n = 0
        continue
        
    q_ids.append(q_id)
    qs.append(q)
    scores.append(score)
    sim_qs.append(sim_q)
    stan_qs.append(stan_q)

# %%
q_test = pd.DataFrame({'q_id': q_ids,
              'q': qs,
              'score': scores,
              'sim_q': sim_qs,
              'stan_q': stan_qs,
              'act_q': act_qs
             })

# %%
q_test
# Out:
#        q_id                       q  score                     sim_q  \
# 0         1                   在哪里领券   1.00                     在哪里领券
# 1         1                   在哪里领券   0.77                请问领劵的地方在哪里
# 2         1                   在哪里领券   0.77                  领劵的页面在哪里
# 3         1                   在哪里领券   0.87                  在哪里可以领劵啊
# 4         1                   在哪里领券   1.00                     劵在哪里领
# 5         1                   在哪里领券   0.77                实名认证领卷在哪里领
# 6         1                   在哪里领券   0.77                  我在哪里可以领劵
# 7         1                   在哪里领券   0.69                请问手机在哪可以领劵
# 8         1                   在哪里领券   0.69                电脑端在哪里可以领劵
# 9         1                   在哪里领券   0.70                 我的新人劵在哪里领
# 10        1                   在哪里领券   0.70               新人劵的领取路径在哪里
# 11        1                   在哪里领券   0.70               我想问下新人劵在哪里领
# 12        1                   在哪里领券   0.69                199元新人劵在哪领
# 13        1                   在哪里领券   0.58                 领取运费券点哪里啊
# 14        1                   在哪里领券   0.58                 在哪里可以领运费劵
# 15        1                   在哪里领券   0.58                   去哪里领运费劵
# 16        2                  电子发票下载   1.00                    电子发票下载
# 17        2                  电子发票下载   0.69               电子发票重复下载可以吗
# 18        2                  电子发票下载   0.81               电子发票一直下载可以吗
# 19        2                  电子发票下载   0.81               电子发票多次下载可以吗
# 20        2                  电子发票下载   0.69               电子发票支持多次下载吗
# 21        2                  电子发票下载   0.69             电子发票下载可以随时下载吧
# 22        2                  电子发票下载   0.68                电子发票可以下载几次
# 23        2                  电子发票下载   0.68                 电子发票要怎么下载
# 24        2                  电子发票下载   0.69              电子发票手机端可以下载吗
# 25        2                  电子发票下载   0.81                  电子发票如何下载
# 26        2                  电子发票下载   0.61               电子发票电脑端怎么下载
# 27        2                  电子发票下载   0.60              电子发票在哪里能够下载呢
# 28        2                  电子发票下载   0.60               电子发票在什么地方下载
# 29        2                  电子发票下载   0.69                我的电子发票如何下载
# 30        2                  电子发票下载   0.60                电子发票如何进行下载
# 31        2                  电子发票下载   0.69                  电子发票哪里下载
# 32        3                 可以改开发票么   0.67                   发票明细能改吗
# 33        3                 可以改开发票么   0.66                发票信息 能不能改？
# 34        3                 可以改开发票么   0.66                能不能改一下发票金额
# 35        3                 可以改开发票么   0.66                  可以改发票税号吗
# 36        3                 可以改开发票么   0.66                  可以改发票抬头吗
# 37        3                 可以改开发票么   0.79               能不能帮我改为纸质发票
# 38        3                 可以改开发票么   0.57                 苏宁卡可以开发票吗
# 39        3                 可以改开发票么   0.66                请问礼品卡能开发票吗
# 40        3                 可以改开发票么   0.61                发票信息是否可以更改
# 41        3                 可以改开发票么   0.62                 发票明细能给我改吗
# 42        3                 可以改开发票么   0.61               发票信息能给我改一下吗
# 43        3                 可以改开发票么   0.61                 能把发票金额改了吗
# 44        3                 可以改开发票么   0.57                 发票税号错了能改吗
# 45        3                 可以改开发票么   0.57                 发票抬头错了能改吗
# 46        3                 可以改开发票么   0.66                 商家商品能开发票吗
# 47        3                 可以改开发票么   0.79                  请问可以开发票吗
# 48        4                    查询物流   1.00                      查询送货
# 49        4                    查询物流   1.00                      查询物流
# ...     ...                     ...    ...                       ...
# 32512  1990                 这款需要变压吗   0.21                为什么任性贷额度变0
# 32513  1991                 你是苏宁客服吗   0.46              你是智能客服还是人工客服
# 32514  1991                 你是苏宁客服吗   0.24                       你是谁
# 32515  1991                 你是苏宁客服吗   0.21                    你是什么东西
# 32516  1991                 你是苏宁客服吗   0.47                 我联系苏宁易购客服
# 32517  1991                 你是苏宁客服吗   0.17                  你是做什么工作的
# 32518  1991                 你是苏宁客服吗   0.19          你是怎么知道itemname的？
# 32519  1991                 你是苏宁客服吗   0.18                     你是死人啊
# 32520  1991                 你是苏宁客服吗   0.14                   你是从哪里发货
# 32521  1991                 你是苏宁客服吗   0.18               你是第三方，不是自营的
# 32522  1991                 你是苏宁客服吗   0.18                你是真人还是人扮的。
# 32523  1991                 你是苏宁客服吗   0.18                 你是24小时服务吗
# 32524  1991                 你是苏宁客服吗   0.16                  你是人工还是电脑
# 32525  1991                 你是苏宁客服吗   0.20                 你是在线人工客服？
# 32526  1991                 你是苏宁客服吗   0.18                 你是机器人吧我不要
# 32527  1991                 你是苏宁客服吗   0.19                  你是人工客服下单
# 32528  1991                 你是苏宁客服吗   0.35               联系苏宁互联客服的方法
# 32529  1991                 你是苏宁客服吗   0.33                苏宁互联有客服电话么
# 32530  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.33          我买的这款移动空调你们给安装吗？
# 32531  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.34        帮我介绍一下你们的空调压缩机十年服务
# 32532  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.34         怎么理解你们这个空调压缩机十年服务
# 32533  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.31                 空调压缩机十年服务
# 32534  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.31            空调压缩机十年服务是厂家修吗
# 32535  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.36            空调压缩机十年服务是苏宁修吗
# 32536  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.31           空调压缩机十年服务是联系厂家吗
# 32537  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.35           空调压缩机十年服务是什么意思？
# 32538  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.33          空调压缩机10年服务是什么意思啊
# 32539  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.27  空调制冷管坏了，你们这个空调压缩机十年服务管用吗
# 32540  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.27    是不是你们这个空调压缩机十年服务保修10年啊
# 32541  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.24      空调压缩机十年服务保修期是从什么时候算起
# 32542  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.26       空调压缩机十年服务，中央空调可以使用吗
# 32543  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.25         挂机空调适用空调压缩机十年服务吗？
# 32544  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.24         柜机空调适用空调压缩机十年服务吗？
# 32545  1992  你好！你这款移动空调是代压缩机吗，厨房可用吗   0.24   如果有空调压缩机十年服务，空调压缩机怎么维修？
# 32546  1993                 我找售后的客服   0.59                     我想找客服
# 32547  1993                 我找售后的客服   0.63                   售后服务找谁啊
# 32548  1993                 我找售后的客服   0.53                   售后有问题找谁
# 32549  1993                 我找售后的客服   0.50               你是说有问题找售后呗？
# 32550  1993                 我找售后的客服   0.50               手机是找您们售后服务吗
# 32551  1993                 我找售后的客服   0.57                如果有售后问题找谁？
# 32552  1993                 我找售后的客服   0.44                售后维修是找苏宁吗？
# 32553  1993                 我找售后的客服   0.50              售后有问题直接找苏宁么？
# 32554  1993                 我找售后的客服   0.54           以后找售后是不是只能找你们苏宁
# 32555  1993                 我找售后的客服   0.50                有问题找你们售后是么
# 32556  1993                 我找售后的客服   0.36                  订单客服在那里找
# 32557  1993                 我找售后的客服   0.47         那售后服务还是要找官方，不找苏宁？
# 32558  1993                 我找售后的客服   0.38          以后质量问题售后维保服务是找哪里
# 32559  1993                 我找售后的客服   0.31               昨晚贵赔提示找在线客服
# 32560  1993                 我找售后的客服   0.35         上次的客服和我说好了找他帮我转一下
# 32561  1993                 我找售后的客服   0.47                      售后维保
#
#                    stan_q               act_q
# 0                   在哪里领券               在哪里领券
# 1                   在哪里领券               在哪里领券
# 2                   在哪里领券               在哪里领券
# 3                   在哪里领券               在哪里领券
# 4                   在哪里领券               在哪里领券
# 5          已经实名认证，为什么没有返券               在哪里领券
# 6                   在哪里领券               在哪里领券
# 7                   在哪里领券               在哪里领券
# 8                   在哪里领券               在哪里领券
# 9                 新人券怎么领取               在哪里领券
# 10                新人券怎么领取               在哪里领券
# 11                新人券怎么领取               在哪里领券
# 12                新人券怎么领取               在哪里领券
# 13                运费券怎么领取               在哪里领券
# 14                运费券怎么领取               在哪里领券
# 15                运费券怎么领取               在哪里领券
# 16     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 17          电子发票下载有没有次数限制  电子发票怎么下载（无下载按钮怎么办）
# 18          电子发票下载有没有次数限制  电子发票怎么下载（无下载按钮怎么办）
# 19          电子发票下载有没有次数限制  电子发票怎么下载（无下载按钮怎么办）
# 20          电子发票下载有没有次数限制  电子发票怎么下载（无下载按钮怎么办）
# 21          电子发票下载有没有次数限制  电子发票怎么下载（无下载按钮怎么办）
# 22          电子发票下载有没有次数限制  电子发票怎么下载（无下载按钮怎么办）
# 23     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 24     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 25     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 26     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 27     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 28     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 29     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 30     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 31     电子发票怎么下载（无下载按钮怎么办）  电子发票怎么下载（无下载按钮怎么办）
# 32             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 33             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 34             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 35             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 36             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 37        电子发票和普通纸质发票怎么互换     电子发票和普通纸质发票怎么互换
# 38              苏宁卡可以开发票吗     电子发票和普通纸质发票怎么互换
# 39              苏宁卡可以开发票吗     电子发票和普通纸质发票怎么互换
# 40             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 41             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 42             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 43             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 44             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 45             发票信息是否可以更改     电子发票和普通纸质发票怎么互换
# 46                  怎么开发票     电子发票和普通纸质发票怎么互换
# 47                  怎么开发票     电子发票和普通纸质发票怎么互换
# 48                   查询送货                查询送货
# 49                   查询送货                查询送货
# ...                   ...                 ...
# 32512       为什么任性贷额度变成了0呢                 转人工
# 32513            你是人工还是电脑                 转人工
# 32514                 你是谁                 转人工
# 32515                 你是谁                 转人工
# 32516                 转人工                 转人工
# 32517            你是做什么工作的                 转人工
# 32518    你是怎么知道itemname的？                 转人工
# 32519               我要投诉你                 转人工
# 32520               从哪里发货                 转人工
# 32521             送货用什么快递                 转人工
# 32522          你是真人还是人扮的。                 转人工
# 32523           你是24小时服务吗                 转人工
# 32524            你是人工还是电脑                 转人工
# 32525            你是人工还是电脑                 转人工
# 32526                 转人工                 转人工
# 32527                 转人工                 转人工
# 32528            苏宁互联服务号码                 转人工
# 32529            苏宁互联服务号码                 转人工
# 32530              怎么预约安装              如何预约维修
# 32531           空调压缩机十年服务              如何预约维修
# 32532           空调压缩机十年服务              如何预约维修
# 32533           空调压缩机十年服务              如何预约维修
# 32534           空调压缩机十年服务              如何预约维修
# 32535           空调压缩机十年服务              如何预约维修
# 32536           空调压缩机十年服务              如何预约维修
# 32537           空调压缩机十年服务              如何预约维修
# 32538           空调压缩机十年服务              如何预约维修
# 32539           空调压缩机十年服务              如何预约维修
# 32540           空调压缩机十年服务              如何预约维修
# 32541           空调压缩机十年服务              如何预约维修
# 32542           空调压缩机十年服务              如何预约维修
# 32543           空调压缩机十年服务              如何预约维修
# 32544           空调压缩机十年服务              如何预约维修
# 32545           空调压缩机十年服务              如何预约维修
# 32546                 转人工              如何预约维修
# 32547              如何预约维修              如何预约维修
# 32548              如何预约维修              如何预约维修
# 32549              如何预约维修              如何预约维修
# 32550              如何预约维修              如何预约维修
# 32551              如何预约维修              如何预约维修
# 32552              如何预约维修              如何预约维修
# 32553              如何预约维修              如何预约维修
# 32554              如何预约维修              如何预约维修
# 32555              如何预约维修              如何预约维修
# 32556                 转人工              如何预约维修
# 32557              如何预约维修              如何预约维修
# 32558              如何预约维修              如何预约维修
# 32559             为什么无法补差              如何预约维修
# 32560                 转人工              如何预约维修
# 32561              如何预约维修              如何预约维修
#
# [32562 rows x 6 columns]
